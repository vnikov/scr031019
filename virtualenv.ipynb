# %% [markdown]
# # Using Virtual Environments
#
# - Difference between virtual environments (virtualenv or venv), containers, and virtual machines
# - Creating a virtual environment
# - Activating and deactivating virtualenvs
# - Installing packages in a virtual environment
# - Using requirements.txt files for reproducability
# - Using wheels for faster installations
# - Cleaning up virtualenvs

# %% [markdown]
# # Virtual Machines, Containers, and Virtualenvs
#
# ## Virtual Machine
#
# - Isolated image ("guest") of a computer running its own operating system
# - Can have different OS than the host
# - Examples: vmware, virtualbox, Amazon EC2
#
# ## Container
#
# - Partially isolated environment that shares the operating system with the host
# - Same OS kernel as host, but with potentially different users/libraries/networks/etc. and system limits
# - Examples: Docker, Heroku, Amazon ECS
#
# ## Virtualenv
#
# - Partially isolated **python** environment running in the same OS as the 'host'
# - **Only** Python packages and environment are isolated:  basically a "private copy of Python"
# - No _security_ isolation from host OS: a program running inside a virtualenv can do whatever a program running outside a virtualenv can do
# - Similar to local `node_modules` subfolder in a project for Javascript developers

# %% [markdown]
# # Why Virtualenvs?
#
# - **Dependency management** - If two different Python applications require two different versions of the same package, running each app in its own virtualenv allows both versions to be available to their respective applications
# - **Keeps your system Python pristine** - Many OSes use Python to implement some of the OS tooling (RedHat in particular). This often results in an older version of Python, or particuar versions of Python packages installed globally that you *should not modify* if you want your system tools to keep working.
# - **Helps with reproducability** - Virtualenvs allow you to note the versions of all packages installed in your venv in order to recreate the virtualenv on another machine. This prevents the "Works on My Machine" certification.

# %% [markdown]
# # Creating a virtualenv
#
#
# ## Installing virtualenv
#
# Since Python 3.3, Python has included a tool to create virtual environments called `venv` in the standard library.
#
# If, however, you are developing on Ubuntu, you must separately install it anyway with `apt-get install python-venv`.

# %% [markdown]
# ## Creating the virtualenv
#
# To create a virtual environment, you invoke the `venv` module with the virtualenv name:
#
# ```shell
# $ python -m venv env-folder
# ```
#
# This command
#
# - creates a folder named `env-folder`
# - copies the Python you used to invoke `venv` into that folder
# - creates a couple of helper scripts inside env-folder to activate/deactivate the virtualenv

# %%
# !which python
# Out:
# /Users/rick446/.virtualenvs/advanced-python/bin/python

# %%
# !python -m venv data/env-folder

# %% [markdown]
# We can see the directory structure that the virtual environment created with the `tree` command. If you don't have `tree`, you can install it on a Mac using homebrew:
#
# ```bash
# $ brew install tree
# ```

# %%
# !tree -d data/env-folder
# Out:
# data/env-folder
# ├── bin
# ├── include
# └── lib
#     └── python3.7
#         └── site-packages
#             ├── __pycache__
#             ├── pip
#             │   ├── __pycache__
#             │   ├── _internal
#             │   │   ├── __pycache__
#             │   │   ├── cli
#             │   │   │   └── __pycache__
#             │   │   ├── commands
#             │   │   │   └── __pycache__
#             │   │   ├── models
#             │   │   │   └── __pycache__
#             │   │   ├── operations
#             │   │   │   └── __pycache__
#             │   │   ├── req
#             │   │   │   └── __pycache__
#             │   │   ├── utils
#             │   │   │   └── __pycache__
#             │   │   └── vcs
#             │   │       └── __pycache__
#             │   └── _vendor
#             │       ├── __pycache__
#             │       ├── cachecontrol
#             │       │   ├── __pycache__
#             │       │   └── caches
#             │       │       └── __pycache__
#             │       ├── certifi
#             │       │   └── __pycache__
#             │       ├── chardet
#             │       │   ├── __pycache__
#             │       │   └── cli
#             │       │       └── __pycache__
#             │       ├── colorama
#             │       │   └── __pycache__
#             │       ├── distlib
#             │       │   ├── __pycache__
#             │       │   └── _backport
#             │       │       └── __pycache__
#             │       ├── html5lib
#             │       │   ├── __pycache__
#             │       │   ├── _trie
#             │       │   │   └── __pycache__
#             │       │   ├── filters
#             │       │   │   └── __pycache__
#             │       │   ├── treeadapters
#             │       │   │   └── __pycache__
#             │       │   ├── treebuilders
#             │       │   │   └── __pycache__
#             │       │   └── treewalkers
#             │       │       └── __pycache__
#             │       ├── idna
#             │       │   └── __pycache__
#             │       ├── lockfile
#             │       │   └── __pycache__
#             │       ├── msgpack
#             │       │   └── __pycache__
#             │       ├── packaging
#             │       │   └── __pycache__
#             │       ├── pep517
#             │       │   └── __pycache__
#             │       ├── pkg_resources
#             │       │   └── __pycache__
#             │       ├── progress
#             │       │   └── __pycache__
#             │       ├── pytoml
#             │       │   └── __pycache__
#             │       ├── requests
#             │       │   └── __pycache__
#             │       ├── urllib3
#             │       │   ├── __pycache__
#             │       │   ├── contrib
#             │       │   │   ├── __pycache__
#             │       │   │   └── _securetransport
#             │       │   │       └── __pycache__
#             │       │   ├── packages
#             │       │   │   ├── __pycache__
#             │       │   │   ├── backports
#             │       │   │   │   └── __pycache__
#             │       │   │   └── ssl_match_hostname
#             │       │   │       └── __pycache__
#             │       │   └── util
#             │       │       └── __pycache__
#             │       └── webencodings
#             │           └── __pycache__
#             ├── pip-18.1.dist-info
#             ├── pkg_resources
#             │   ├── __pycache__
#             │   ├── _vendor
#             │   │   ├── __pycache__
#             │   │   └── packaging
#             │   │       └── __pycache__
#             │   └── extern
#             │       └── __pycache__
#             ├── setuptools
#             │   ├── __pycache__
#             │   ├── _vendor
#             │   │   ├── __pycache__
#             │   │   └── packaging
#             │   │       └── __pycache__
#             │   ├── command
#             │   │   └── __pycache__
#             │   └── extern
#             │       └── __pycache__
#             └── setuptools-40.6.2.dist-info
#
# 108 directories

# %%
ls data/env-folder/bin
# Out:
# activate          easy_install*     pip3*             python3@
# activate.csh      easy_install-3.7* pip3.7*
# activate.fish     pip*              python@

# %% [markdown]
# ### (windows note)
#
# If you are using Windows, there should be a `Scripts` folder under the environment folder instead of `bin`, and it should contain an `activate.bat` file.

# %% [markdown]
# You can invoke the Python in your new virtualenv by specifying the full path:

# %%
# !data/env-folder/bin/python --version
# Out:
# Python 3.7.2

# %%
# !data/env-folder/bin/python -c 'import sys; print(sys.executable)'
# Out:
# /Users/rick446/src/arborian-classes/data/env-folder/bin/python

# %% [markdown]
# ## Activating virtual environments
#
# More commonly, we will *activate* the virtualenv for our current shell by `source`-ing the `activate` script
#
# ### Linux
#
# ```shell
# $ source env-folder/bin/activate
# (env-folder) $
# ```
#
# or
#
# ```shell
# $ . env-folder/bin/activate
# (env-folder) $
# ```
#
# ### Windows
#
# ```shell
# c:\...> env-folder\Scripts\activate.bat
# (env-folder) c:\...>
# ```
#
# Activating the virtualenv does a few things to your *current shell/terminal window only*:
#
# - Puts the virtualenv's executable folder (`bin` or `Scripts`) at the beginning of your path so the virtualenv python will be picked up automatically
# - Changes your prompt so you see that you are in the virtualenv
# - Makes a `deactivate` command available to undo the changes

# %% [markdown]
# ## Deactivating virtual environments
#
# ### Linux
#
# ```shell
# (env-folder) $ deactivate
# $
# ```
#
# ### Windows
#
# ```shell
# (env-folder) c:\...> deactivate
# c:\...>
# ```

# %%
# %%bash
# source data/env-folder/bin/activate
# which python
# echo My prompt is now $PS1
# python -c 'import sys; print(sys.executable)'
# deactivate
# which python
# python -c 'import sys; print(sys.executable)'
# Out:
# /Users/rick446/src/arborian-classes/src/data/env-folder/bin/python
# My prompt is now (env-folder)
# /Users/rick446/src/arborian-classes/data/env-folder/bin/python
# /Users/rick446/.virtualenvs/advanced-python/bin/python
# /Users/rick446/.virtualenvs/advanced-python/bin/python

# %% [markdown]
# # Installing packages in virtual environments
#
# When the virtual environment is activated, or when you invoke the version of Python in the virtualenv, you can install third-party packages into the virtualenv without modifying your system Python:

# %%
# %%bash
# set -e
# source data/env-folder/bin/activate
# which python
# python -m pip install -U pip
# python -m pip install numpy
# python -c 'import numpy; print(numpy)'
# Out:
# /Users/rick446/src/arborian-classes/src/data/env-folder/bin/python
# Collecting pip
#   Using cached https://files.pythonhosted.org/packages/d8/f3/413bab4ff08e1fc4828dfc59996d721917df8e8583ea85385d51125dceff/pip-19.0.3-py2.py3-none-any.whl
# Installing collected packages: pip
#   Found existing installation: pip 18.1
#     Uninstalling pip-18.1:
#       Successfully uninstalled pip-18.1
# Successfully installed pip-19.0.3
# Collecting numpy
#   Using cached https://files.pythonhosted.org/packages/a6/6f/cb20ccd8f0f8581e0e090775c0e3c3e335b037818416e6fa945d924397d2/numpy-1.16.2-cp37-cp37m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl
# Installing collected packages: numpy
# Successfully installed numpy-1.16.2
# <module 'numpy' from '/Users/rick446/src/arborian-classes/data/env-folder/lib/python3.7/site-packages/numpy/__init__.py'>

# %% [markdown]
# # Using requirements.txt for reproducibility
#
# Once you have your app in your virtualenv running, you may need to reproduce the virtualenv on another machine.
# `pip` has a command `freeze` which outputs the exact versions of all packages installed in a virtualenv:

# %%
# %%bash
# set -e
# source data/env-folder/bin/activate
# python -m pip freeze
# Out:
# numpy==1.16.2

# %% [markdown]
# Normally, we'll put this into a file `requirements.txt` that we check into source control and distribute with our project:

# %%
# %%bash
# set -e
# source data/env-folder/bin/activate
# pip freeze > data/requirements.txt

# %% [markdown]
# Once we have the requirements.txt file, we can create a new virtualenv and install all the same versions of packages into it:

# %%
# %%bash
# set -e
# python -m venv data/env-folder-2
# source data/env-folder-2/bin/activate
# pip install -r data/requirements.txt
# Out:
# Collecting numpy==1.16.2 (from -r data/requirements.txt (line 1))
#   Using cached https://files.pythonhosted.org/packages/a6/6f/cb20ccd8f0f8581e0e090775c0e3c3e335b037818416e6fa945d924397d2/numpy-1.16.2-cp37-cp37m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl
# Installing collected packages: numpy
# Successfully installed numpy-1.16.2
# You are using pip version 18.1, however version 19.0.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# # Using wheels for faster installations
#
# While `pip` tries to cache as much data as possible, we can do even better by using "wheels."
#
# Wheels are Python packages that have been compiled (if necessary) for a particular target architecture and are thus much faster to install.
#
# If you're moving to a new machine (for instance, when deploying to production) it can also be useful to have the wheels cached locally so `pip` doesn't try to download the packages from the Python Package Index.

# %%
# %%bash
# set -e
# source data/env-folder/bin/activate
# pip install scipy sklearn jupyter simplejson pymongo boto3 wheel
# pip freeze > data/requirements.txt
# Out:
# Collecting scipy
#   Using cached https://files.pythonhosted.org/packages/dd/6c/ccf7403d14f0ab0f20ce611696921f204f4ffce99a4fd383c892a6a7e9eb/scipy-1.2.1-cp37-cp37m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl
# Collecting sklearn
# Collecting jupyter
#   Using cached https://files.pythonhosted.org/packages/83/df/0f5dd132200728a86190397e1ea87cd76244e42d39ec5e88efd25b2abd7e/jupyter-1.0.0-py2.py3-none-any.whl
# Collecting simplejson
# Collecting pymongo
#   Using cached https://files.pythonhosted.org/packages/d7/ac/d2e324c1f9bcf653fa106785371a16b4709506a35b04948655de8b961a85/pymongo-3.7.2-cp37-cp37m-macosx_10_9_x86_64.whl
# Collecting boto3
#   Downloading https://files.pythonhosted.org/packages/68/52/7c0ffae88a765f020e3e85de7d02d64c1b67f8fe78c1d79c5586a493ebf9/boto3-1.9.118-py2.py3-none-any.whl (128kB)
# Collecting wheel
#   Using cached https://files.pythonhosted.org/packages/96/ba/a4702cbb6a3a485239fbe9525443446203f00771af9ac000fa3ef2788201/wheel-0.33.1-py2.py3-none-any.whl
# Requirement already satisfied: numpy>=1.8.2 in /Users/rick446/src/arborian-classes/data/env-folder/lib/python3.7/site-packages (from scipy) (1.16.2)
# Collecting scikit-learn (from sklearn)
#   Using cached https://files.pythonhosted.org/packages/bd/1a/5dc99dfa7e7bf2e1f22a07f440b61299148a42d13dee1d5153360313ed67/scikit_learn-0.20.3-cp37-cp37m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl
# Collecting nbconvert (from jupyter)
#   Using cached https://files.pythonhosted.org/packages/b8/39/1e67fea74dc9577cc49f9863fe3ec824e525d1304ab6027d95a94cd586f5/nbconvert-5.4.1-py2.py3-none-any.whl
# Collecting ipywidgets (from jupyter)
#   Using cached https://files.pythonhosted.org/packages/30/9a/a008c7b1183fac9e52066d80a379b3c64eab535bd9d86cdc29a0b766fd82/ipywidgets-7.4.2-py2.py3-none-any.whl
# Collecting notebook (from jupyter)
#   Using cached https://files.pythonhosted.org/packages/0a/d8/4e9521354ed3d730ba6d8a5af440b66c73245ef46be706e51bead71afc21/notebook-5.7.6-py2.py3-none-any.whl
# Collecting ipykernel (from jupyter)
#   Using cached https://files.pythonhosted.org/packages/d8/b0/f0be5c5ab335196f5cce96e5b889a4fcf5bfe462eb0acc05cd7e2caf65eb/ipykernel-5.1.0-py3-none-any.whl
# Collecting jupyter-console (from jupyter)
#   Using cached https://files.pythonhosted.org/packages/cb/ee/6374ae8c21b7d0847f9c3722dcdfac986b8e54fa9ad9ea66e1eb6320d2b8/jupyter_console-6.0.0-py2.py3-none-any.whl
# Collecting qtconsole (from jupyter)
#   Using cached https://files.pythonhosted.org/packages/e0/7a/8aefbc0ed078dec7951ac9a06dcd1869243ecd7bcbce26fa47bf5e469a8f/qtconsole-4.4.3-py2.py3-none-any.whl
# Collecting s3transfer<0.3.0,>=0.2.0 (from boto3)
#   Using cached https://files.pythonhosted.org/packages/d7/de/5737f602e22073ecbded7a0c590707085e154e32b68d86545dcc31004c02/s3transfer-0.2.0-py2.py3-none-any.whl
# Collecting botocore<1.13.0,>=1.12.118 (from boto3)
#   Downloading https://files.pythonhosted.org/packages/0c/2d/67bbe92954c680726b6c1ef1fd57e07fa6d927c049ae7a6c983026926063/botocore-1.12.118-py2.py3-none-any.whl (5.3MB)
# Collecting jmespath<1.0.0,>=0.7.1 (from boto3)
#   Using cached https://files.pythonhosted.org/packages/83/94/7179c3832a6d45b266ddb2aac329e101367fbdb11f425f13771d27f225bb/jmespath-0.9.4-py2.py3-none-any.whl
# Collecting traitlets>=4.2 (from nbconvert->jupyter)
#   Using cached https://files.pythonhosted.org/packages/93/d6/abcb22de61d78e2fc3959c964628a5771e47e7cc60d53e9342e21ed6cc9a/traitlets-4.3.2-py2.py3-none-any.whl
# Collecting testpath (from nbconvert->jupyter)
#   Using cached https://files.pythonhosted.org/packages/be/a4/162f9ebb6489421fe46dcca2ae420369edfee4b563c668d93cb4605d12ba/testpath-0.4.2-py2.py3-none-any.whl
# Collecting pandocfilters>=1.4.1 (from nbconvert->jupyter)
# Collecting nbformat>=4.4 (from nbconvert->jupyter)
#   Using cached https://files.pythonhosted.org/packages/da/27/9a654d2b6cc1eaa517d1c5a4405166c7f6d72f04f6e7eea41855fe808a46/nbformat-4.4.0-py2.py3-none-any.whl
# Collecting jinja2 (from nbconvert->jupyter)
#   Using cached https://files.pythonhosted.org/packages/7f/ff/ae64bacdfc95f27a016a7bed8e8686763ba4d277a78ca76f32659220a731/Jinja2-2.10-py2.py3-none-any.whl
# Collecting bleach (from nbconvert->jupyter)
#   Using cached https://files.pythonhosted.org/packages/ab/05/27e1466475e816d3001efb6e0a85a819be17411420494a1e602c36f8299d/bleach-3.1.0-py2.py3-none-any.whl
# Collecting entrypoints>=0.2.2 (from nbconvert->jupyter)
#   Using cached https://files.pythonhosted.org/packages/ac/c6/44694103f8c221443ee6b0041f69e2740d89a25641e62fb4f2ee568f2f9c/entrypoints-0.3-py2.py3-none-any.whl
# Collecting defusedxml (from nbconvert->jupyter)
#   Using cached https://files.pythonhosted.org/packages/87/1c/17f3e3935a913dfe2a5ca85fa5ccbef366bfd82eb318b1f75dadbf0affca/defusedxml-0.5.0-py2.py3-none-any.whl
# Collecting jupyter-core (from nbconvert->jupyter)
#   Using cached https://files.pythonhosted.org/packages/1d/44/065d2d7bae7bebc06f1dd70d23c36da8c50c0f08b4236716743d706762a8/jupyter_core-4.4.0-py2.py3-none-any.whl
# Collecting mistune>=0.8.1 (from nbconvert->jupyter)
#   Using cached https://files.pythonhosted.org/packages/09/ec/4b43dae793655b7d8a25f76119624350b4d65eb663459eb9603d7f1f0345/mistune-0.8.4-py2.py3-none-any.whl
# Collecting pygments (from nbconvert->jupyter)
#   Using cached https://files.pythonhosted.org/packages/13/e5/6d710c9cf96c31ac82657bcfb441df328b22df8564d58d0c4cd62612674c/Pygments-2.3.1-py2.py3-none-any.whl
# Collecting widgetsnbextension~=3.4.0 (from ipywidgets->jupyter)
#   Using cached https://files.pythonhosted.org/packages/8a/81/35789a3952afb48238289171728072d26d6e76649ddc8b3588657a2d78c1/widgetsnbextension-3.4.2-py2.py3-none-any.whl
# Collecting ipython>=4.0.0; python_version >= "3.3" (from ipywidgets->jupyter)
#   Using cached https://files.pythonhosted.org/packages/14/3b/3fcf422a99a04ee493e6a4fc3014e3c8ff484a7feed238fef68bdc285085/ipython-7.3.0-py3-none-any.whl
# Collecting Send2Trash (from notebook->jupyter)
#   Using cached https://files.pythonhosted.org/packages/49/46/c3dc27481d1cc57b9385aff41c474ceb7714f7935b1247194adae45db714/Send2Trash-1.5.0-py3-none-any.whl
# Collecting tornado<7,>=4.1 (from notebook->jupyter)
#   Using cached https://files.pythonhosted.org/packages/b1/7f/8109821ff9df1bf3519169e34646705c32ac13be6a4d51a79ed57f47686e/tornado-6.0.1.tar.gz
# Collecting pyzmq>=17 (from notebook->jupyter)
#   Using cached https://files.pythonhosted.org/packages/30/08/64b910e8f5e0285598a15a8d8f2f4d06a1367f0d145c7554fdd02d926272/pyzmq-18.0.1-cp37-cp37m-macosx_10_9_x86_64.whl
# Collecting ipython-genutils (from notebook->jupyter)
#   Using cached https://files.pythonhosted.org/packages/fa/bc/9bd3b5c2b4774d5f33b2d544f1460be9df7df2fe42f352135381c347c69a/ipython_genutils-0.2.0-py2.py3-none-any.whl
# Collecting jupyter-client>=5.2.0 (from notebook->jupyter)
#   Using cached https://files.pythonhosted.org/packages/3b/c3/3043fe9ffd140d03c9d091a056794ccdc427c56ec19b8eea74f9ea0a498f/jupyter_client-5.2.4-py2.py3-none-any.whl
# Collecting terminado>=0.8.1 (from notebook->jupyter)
#   Using cached https://files.pythonhosted.org/packages/2e/20/a26211a24425923d46e1213b376a6ee60dc30bcdf1b0c345e2c3769deb1c/terminado-0.8.1-py2.py3-none-any.whl
# Collecting prometheus-client (from notebook->jupyter)
#   Using cached https://files.pythonhosted.org/packages/4c/bd/b42db3ec90ffc6be805aad09c1cea4bb13a620d0cd4b21aaa44d13541d71/prometheus_client-0.6.0.tar.gz
# Collecting prompt-toolkit<2.1.0,>=2.0.0 (from jupyter-console->jupyter)
#   Using cached https://files.pythonhosted.org/packages/f7/a7/9b1dd14ef45345f186ef69d175bdd2491c40ab1dfa4b2b3e4352df719ed7/prompt_toolkit-2.0.9-py3-none-any.whl
# Collecting python-dateutil<3.0.0,>=2.1; python_version >= "2.7" (from botocore<1.13.0,>=1.12.118->boto3)
#   Using cached https://files.pythonhosted.org/packages/41/17/c62faccbfbd163c7f57f3844689e3a78bae1f403648a6afb1d0866d87fbb/python_dateutil-2.8.0-py2.py3-none-any.whl
# Collecting urllib3<1.25,>=1.20; python_version >= "3.4" (from botocore<1.13.0,>=1.12.118->boto3)
#   Using cached https://files.pythonhosted.org/packages/62/00/ee1d7de624db8ba7090d1226aebefab96a2c71cd5cfa7629d6ad3f61b79e/urllib3-1.24.1-py2.py3-none-any.whl
# Collecting docutils>=0.10 (from botocore<1.13.0,>=1.12.118->boto3)
#   Using cached https://files.pythonhosted.org/packages/36/fa/08e9e6e0e3cbd1d362c3bbee8d01d0aedb2155c4ac112b19ef3cae8eed8d/docutils-0.14-py3-none-any.whl
# Collecting decorator (from traitlets>=4.2->nbconvert->jupyter)
#   Downloading https://files.pythonhosted.org/packages/5f/88/0075e461560a1e750a0dcbf77f1d9de775028c37a19a346a6c565a257399/decorator-4.4.0-py2.py3-none-any.whl
# Collecting six (from traitlets>=4.2->nbconvert->jupyter)
#   Using cached https://files.pythonhosted.org/packages/73/fb/00a976f728d0d1fecfe898238ce23f502a721c0ac0ecfedb80e0d88c64e9/six-1.12.0-py2.py3-none-any.whl
# Collecting jsonschema!=2.5.0,>=2.4 (from nbformat>=4.4->nbconvert->jupyter)
#   Using cached https://files.pythonhosted.org/packages/aa/69/df679dfbdd051568b53c38ec8152a3ab6bc533434fc7ed11ab034bf5e82f/jsonschema-3.0.1-py2.py3-none-any.whl
# Collecting MarkupSafe>=0.23 (from jinja2->nbconvert->jupyter)
#   Using cached https://files.pythonhosted.org/packages/ce/c6/f000f1af136ef74e4a95e33785921c73595c5390403f102e9b231b065b7a/MarkupSafe-1.1.1-cp37-cp37m-macosx_10_6_intel.whl
# Collecting webencodings (from bleach->nbconvert->jupyter)
#   Using cached https://files.pythonhosted.org/packages/f4/24/2a3e3df732393fed8b3ebf2ec078f05546de641fe1b667ee316ec1dcf3b7/webencodings-0.5.1-py2.py3-none-any.whl
# Collecting jedi>=0.10 (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter)
#   Using cached https://files.pythonhosted.org/packages/25/2b/1f188901be099d52d7b06f4d3b7cb9f8f09692c50697b139eaf6fa2928d8/jedi-0.13.3-py2.py3-none-any.whl
# Collecting backcall (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter)
# Collecting pickleshare (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter)
#   Using cached https://files.pythonhosted.org/packages/9a/41/220f49aaea88bc6fa6cba8d05ecf24676326156c23b991e80b3f2fc24c77/pickleshare-0.7.5-py2.py3-none-any.whl
# Requirement already satisfied: setuptools>=18.5 in /Users/rick446/src/arborian-classes/data/env-folder/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter) (40.6.2)
# Collecting appnope; sys_platform == "darwin" (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter)
#   Using cached https://files.pythonhosted.org/packages/87/a9/7985e6a53402f294c8f0e8eff3151a83f1fb901fa92909bb3ff29b4d22af/appnope-0.1.0-py2.py3-none-any.whl
# Collecting pexpect; sys_platform != "win32" (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter)
#   Using cached https://files.pythonhosted.org/packages/89/e6/b5a1de8b0cc4e07ca1b305a4fcc3f9806025c1b651ea302646341222f88b/pexpect-4.6.0-py2.py3-none-any.whl
# Collecting ptyprocess; os_name != "nt" (from terminado>=0.8.1->notebook->jupyter)
#   Using cached https://files.pythonhosted.org/packages/d1/29/605c2cc68a9992d18dada28206eeada56ea4bd07a239669da41674648b6f/ptyprocess-0.6.0-py2.py3-none-any.whl
# Collecting wcwidth (from prompt-toolkit<2.1.0,>=2.0.0->jupyter-console->jupyter)
#   Using cached https://files.pythonhosted.org/packages/7e/9f/526a6947247599b084ee5232e4f9190a38f398d7300d866af3ab571a5bfe/wcwidth-0.1.7-py2.py3-none-any.whl
# Collecting pyrsistent>=0.14.0 (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert->jupyter)
#   Using cached https://files.pythonhosted.org/packages/8c/46/4e93ab8a379d7efe93f20a0fb8a27bdfe88942cc954ab0210c3164e783e0/pyrsistent-0.14.11.tar.gz
# Collecting attrs>=17.4.0 (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert->jupyter)
#   Using cached https://files.pythonhosted.org/packages/23/96/d828354fa2dbdf216eaa7b7de0db692f12c234f7ef888cc14980ef40d1d2/attrs-19.1.0-py2.py3-none-any.whl
# Collecting parso>=0.3.0 (from jedi>=0.10->ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter)
#   Using cached https://files.pythonhosted.org/packages/19/b1/522b2671cc6d134c9d3f5dfc0d02fee07cab848e908d03d2bffea78cca8f/parso-0.3.4-py2.py3-none-any.whl
# Installing collected packages: scipy, scikit-learn, sklearn, decorator, ipython-genutils, six, traitlets, testpath, pandocfilters, jupyter-core, pyrsistent, attrs, jsonschema, nbformat, MarkupSafe, jinja2, webencodings, bleach, entrypoints, defusedxml, mistune, pygments, nbconvert, Send2Trash, tornado, pyzmq, python-dateutil, jupyter-client, parso, jedi, backcall, pickleshare, appnope, wcwidth, prompt-toolkit, ptyprocess, pexpect, ipython, ipykernel, terminado, prometheus-client, notebook, widgetsnbextension, ipywidgets, jupyter-console, qtconsole, jupyter, simplejson, pymongo, urllib3, docutils, jmespath, botocore, s3transfer, boto3, wheel
#   Running setup.py install for pyrsistent: started
#     Running setup.py install for pyrsistent: finished with status 'done'
#   Running setup.py install for tornado: started
#     Running setup.py install for tornado: finished with status 'done'
#   Running setup.py install for prometheus-client: started
#     Running setup.py install for prometheus-client: finished with status 'done'
# Successfully installed MarkupSafe-1.1.1 Send2Trash-1.5.0 appnope-0.1.0 attrs-19.1.0 backcall-0.1.0 bleach-3.1.0 boto3-1.9.118 botocore-1.12.118 decorator-4.4.0 defusedxml-0.5.0 docutils-0.14 entrypoints-0.3 ipykernel-5.1.0 ipython-7.3.0 ipython-genutils-0.2.0 ipywidgets-7.4.2 jedi-0.13.3 jinja2-2.10 jmespath-0.9.4 jsonschema-3.0.1 jupyter-1.0.0 jupyter-client-5.2.4 jupyter-console-6.0.0 jupyter-core-4.4.0 mistune-0.8.4 nbconvert-5.4.1 nbformat-4.4.0 notebook-5.7.6 pandocfilters-1.4.2 parso-0.3.4 pexpect-4.6.0 pickleshare-0.7.5 prometheus-client-0.6.0 prompt-toolkit-2.0.9 ptyprocess-0.6.0 pygments-2.3.1 pymongo-3.7.2 pyrsistent-0.14.11 python-dateutil-2.8.0 pyzmq-18.0.1 qtconsole-4.4.3 s3transfer-0.2.0 scikit-learn-0.20.3 scipy-1.2.1 simplejson-3.16.0 six-1.12.0 sklearn-0.0 terminado-0.8.1 testpath-0.4.2 tornado-6.0.1 traitlets-4.3.2 urllib3-1.24.1 wcwidth-0.1.7 webencodings-0.5.1 wheel-0.33.1 widgetsnbextension-3.4.2

# %%
cat data/requirements.txt
# Out:
# appnope==0.1.0
# attrs==19.1.0
# backcall==0.1.0
# bleach==3.1.0
# boto3==1.9.118
# botocore==1.12.118
# decorator==4.4.0
# defusedxml==0.5.0
# docutils==0.14
# entrypoints==0.3
# ipykernel==5.1.0
# ipython==7.3.0
# ipython-genutils==0.2.0
# ipywidgets==7.4.2
# jedi==0.13.3
# Jinja2==2.10
# jmespath==0.9.4
# jsonschema==3.0.1
# jupyter==1.0.0
# jupyter-client==5.2.4
# jupyter-console==6.0.0
# jupyter-core==4.4.0
# MarkupSafe==1.1.1
# mistune==0.8.4
# nbconvert==5.4.1
# nbformat==4.4.0
# notebook==5.7.6
# numpy==1.16.2
# pandocfilters==1.4.2
# parso==0.3.4
# pexpect==4.6.0
# pickleshare==0.7.5
# prometheus-client==0.6.0
# prompt-toolkit==2.0.9
# ptyprocess==0.6.0
# Pygments==2.3.1
# pymongo==3.7.2
# pyrsistent==0.14.11
# python-dateutil==2.8.0
# pyzmq==18.0.1
# qtconsole==4.4.3
# s3transfer==0.2.0
# scikit-learn==0.20.3
# scipy==1.2.1
# Send2Trash==1.5.0
# simplejson==3.16.0
# six==1.12.0
# sklearn==0.0
# terminado==0.8.1
# testpath==0.4.2
# tornado==6.0.1
# traitlets==4.3.2
# urllib3==1.24.1
# wcwidth==0.1.7
# webencodings==0.5.1
# widgetsnbextension==3.4.2

# %%
# %%bash
# set -e
# source data/env-folder/bin/activate
# pip wheel -w data/wheelhouse -r data/requirements.txt
# Out:
# Collecting appnope==0.1.0 (from -r data/requirements.txt (line 1))
#   Using cached https://files.pythonhosted.org/packages/87/a9/7985e6a53402f294c8f0e8eff3151a83f1fb901fa92909bb3ff29b4d22af/appnope-0.1.0-py2.py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/appnope-0.1.0-py2.py3-none-any.whl
# Collecting attrs==19.1.0 (from -r data/requirements.txt (line 2))
#   Using cached https://files.pythonhosted.org/packages/23/96/d828354fa2dbdf216eaa7b7de0db692f12c234f7ef888cc14980ef40d1d2/attrs-19.1.0-py2.py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/attrs-19.1.0-py2.py3-none-any.whl
# Collecting backcall==0.1.0 (from -r data/requirements.txt (line 3))
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/backcall-0.1.0-cp37-none-any.whl
# Collecting bleach==3.1.0 (from -r data/requirements.txt (line 4))
#   Using cached https://files.pythonhosted.org/packages/ab/05/27e1466475e816d3001efb6e0a85a819be17411420494a1e602c36f8299d/bleach-3.1.0-py2.py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/bleach-3.1.0-py2.py3-none-any.whl
# Collecting boto3==1.9.118 (from -r data/requirements.txt (line 5))
#   Using cached https://files.pythonhosted.org/packages/68/52/7c0ffae88a765f020e3e85de7d02d64c1b67f8fe78c1d79c5586a493ebf9/boto3-1.9.118-py2.py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/boto3-1.9.118-py2.py3-none-any.whl
# Collecting botocore==1.12.118 (from -r data/requirements.txt (line 6))
#   Using cached https://files.pythonhosted.org/packages/0c/2d/67bbe92954c680726b6c1ef1fd57e07fa6d927c049ae7a6c983026926063/botocore-1.12.118-py2.py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/botocore-1.12.118-py2.py3-none-any.whl
# Collecting decorator==4.4.0 (from -r data/requirements.txt (line 7))
#   Using cached https://files.pythonhosted.org/packages/5f/88/0075e461560a1e750a0dcbf77f1d9de775028c37a19a346a6c565a257399/decorator-4.4.0-py2.py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/decorator-4.4.0-py2.py3-none-any.whl
# Collecting defusedxml==0.5.0 (from -r data/requirements.txt (line 8))
#   Using cached https://files.pythonhosted.org/packages/87/1c/17f3e3935a913dfe2a5ca85fa5ccbef366bfd82eb318b1f75dadbf0affca/defusedxml-0.5.0-py2.py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/defusedxml-0.5.0-py2.py3-none-any.whl
# Collecting docutils==0.14 (from -r data/requirements.txt (line 9))
#   Using cached https://files.pythonhosted.org/packages/36/fa/08e9e6e0e3cbd1d362c3bbee8d01d0aedb2155c4ac112b19ef3cae8eed8d/docutils-0.14-py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/docutils-0.14-py3-none-any.whl
# Collecting entrypoints==0.3 (from -r data/requirements.txt (line 10))
#   Using cached https://files.pythonhosted.org/packages/ac/c6/44694103f8c221443ee6b0041f69e2740d89a25641e62fb4f2ee568f2f9c/entrypoints-0.3-py2.py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/entrypoints-0.3-py2.py3-none-any.whl
# Collecting ipykernel==5.1.0 (from -r data/requirements.txt (line 11))
#   Using cached https://files.pythonhosted.org/packages/d8/b0/f0be5c5ab335196f5cce96e5b889a4fcf5bfe462eb0acc05cd7e2caf65eb/ipykernel-5.1.0-py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/ipykernel-5.1.0-py3-none-any.whl
# Collecting ipython==7.3.0 (from -r data/requirements.txt (line 12))
#   Using cached https://files.pythonhosted.org/packages/14/3b/3fcf422a99a04ee493e6a4fc3014e3c8ff484a7feed238fef68bdc285085/ipython-7.3.0-py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/ipython-7.3.0-py3-none-any.whl
# Collecting ipython-genutils==0.2.0 (from -r data/requirements.txt (line 13))
#   Using cached https://files.pythonhosted.org/packages/fa/bc/9bd3b5c2b4774d5f33b2d544f1460be9df7df2fe42f352135381c347c69a/ipython_genutils-0.2.0-py2.py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/ipython_genutils-0.2.0-py2.py3-none-any.whl
# Collecting ipywidgets==7.4.2 (from -r data/requirements.txt (line 14))
#   Using cached https://files.pythonhosted.org/packages/30/9a/a008c7b1183fac9e52066d80a379b3c64eab535bd9d86cdc29a0b766fd82/ipywidgets-7.4.2-py2.py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/ipywidgets-7.4.2-py2.py3-none-any.whl
# Collecting jedi==0.13.3 (from -r data/requirements.txt (line 15))
#   Using cached https://files.pythonhosted.org/packages/25/2b/1f188901be099d52d7b06f4d3b7cb9f8f09692c50697b139eaf6fa2928d8/jedi-0.13.3-py2.py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/jedi-0.13.3-py2.py3-none-any.whl
# Collecting Jinja2==2.10 (from -r data/requirements.txt (line 16))
#   Using cached https://files.pythonhosted.org/packages/7f/ff/ae64bacdfc95f27a016a7bed8e8686763ba4d277a78ca76f32659220a731/Jinja2-2.10-py2.py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/Jinja2-2.10-py2.py3-none-any.whl
# Collecting jmespath==0.9.4 (from -r data/requirements.txt (line 17))
#   Using cached https://files.pythonhosted.org/packages/83/94/7179c3832a6d45b266ddb2aac329e101367fbdb11f425f13771d27f225bb/jmespath-0.9.4-py2.py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/jmespath-0.9.4-py2.py3-none-any.whl
# Collecting jsonschema==3.0.1 (from -r data/requirements.txt (line 18))
#   Using cached https://files.pythonhosted.org/packages/aa/69/df679dfbdd051568b53c38ec8152a3ab6bc533434fc7ed11ab034bf5e82f/jsonschema-3.0.1-py2.py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/jsonschema-3.0.1-py2.py3-none-any.whl
# Collecting jupyter==1.0.0 (from -r data/requirements.txt (line 19))
#   Using cached https://files.pythonhosted.org/packages/83/df/0f5dd132200728a86190397e1ea87cd76244e42d39ec5e88efd25b2abd7e/jupyter-1.0.0-py2.py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/jupyter-1.0.0-py2.py3-none-any.whl
# Collecting jupyter-client==5.2.4 (from -r data/requirements.txt (line 20))
#   Using cached https://files.pythonhosted.org/packages/3b/c3/3043fe9ffd140d03c9d091a056794ccdc427c56ec19b8eea74f9ea0a498f/jupyter_client-5.2.4-py2.py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/jupyter_client-5.2.4-py2.py3-none-any.whl
# Collecting jupyter-console==6.0.0 (from -r data/requirements.txt (line 21))
#   Using cached https://files.pythonhosted.org/packages/cb/ee/6374ae8c21b7d0847f9c3722dcdfac986b8e54fa9ad9ea66e1eb6320d2b8/jupyter_console-6.0.0-py2.py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/jupyter_console-6.0.0-py2.py3-none-any.whl
# Collecting jupyter-core==4.4.0 (from -r data/requirements.txt (line 22))
#   Using cached https://files.pythonhosted.org/packages/1d/44/065d2d7bae7bebc06f1dd70d23c36da8c50c0f08b4236716743d706762a8/jupyter_core-4.4.0-py2.py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/jupyter_core-4.4.0-py2.py3-none-any.whl
# Collecting MarkupSafe==1.1.1 (from -r data/requirements.txt (line 23))
#   Using cached https://files.pythonhosted.org/packages/ce/c6/f000f1af136ef74e4a95e33785921c73595c5390403f102e9b231b065b7a/MarkupSafe-1.1.1-cp37-cp37m-macosx_10_6_intel.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/MarkupSafe-1.1.1-cp37-cp37m-macosx_10_6_intel.whl
# Collecting mistune==0.8.4 (from -r data/requirements.txt (line 24))
#   Using cached https://files.pythonhosted.org/packages/09/ec/4b43dae793655b7d8a25f76119624350b4d65eb663459eb9603d7f1f0345/mistune-0.8.4-py2.py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/mistune-0.8.4-py2.py3-none-any.whl
# Collecting nbconvert==5.4.1 (from -r data/requirements.txt (line 25))
#   Using cached https://files.pythonhosted.org/packages/b8/39/1e67fea74dc9577cc49f9863fe3ec824e525d1304ab6027d95a94cd586f5/nbconvert-5.4.1-py2.py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/nbconvert-5.4.1-py2.py3-none-any.whl
# Collecting nbformat==4.4.0 (from -r data/requirements.txt (line 26))
#   Using cached https://files.pythonhosted.org/packages/da/27/9a654d2b6cc1eaa517d1c5a4405166c7f6d72f04f6e7eea41855fe808a46/nbformat-4.4.0-py2.py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/nbformat-4.4.0-py2.py3-none-any.whl
# Collecting notebook==5.7.6 (from -r data/requirements.txt (line 27))
#   Using cached https://files.pythonhosted.org/packages/0a/d8/4e9521354ed3d730ba6d8a5af440b66c73245ef46be706e51bead71afc21/notebook-5.7.6-py2.py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/notebook-5.7.6-py2.py3-none-any.whl
# Collecting numpy==1.16.2 (from -r data/requirements.txt (line 28))
#   Using cached https://files.pythonhosted.org/packages/a6/6f/cb20ccd8f0f8581e0e090775c0e3c3e335b037818416e6fa945d924397d2/numpy-1.16.2-cp37-cp37m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/numpy-1.16.2-cp37-cp37m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl
# Collecting pandocfilters==1.4.2 (from -r data/requirements.txt (line 29))
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/pandocfilters-1.4.2-cp37-none-any.whl
# Collecting parso==0.3.4 (from -r data/requirements.txt (line 30))
#   Using cached https://files.pythonhosted.org/packages/19/b1/522b2671cc6d134c9d3f5dfc0d02fee07cab848e908d03d2bffea78cca8f/parso-0.3.4-py2.py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/parso-0.3.4-py2.py3-none-any.whl
# Collecting pexpect==4.6.0 (from -r data/requirements.txt (line 31))
#   Using cached https://files.pythonhosted.org/packages/89/e6/b5a1de8b0cc4e07ca1b305a4fcc3f9806025c1b651ea302646341222f88b/pexpect-4.6.0-py2.py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/pexpect-4.6.0-py2.py3-none-any.whl
# Collecting pickleshare==0.7.5 (from -r data/requirements.txt (line 32))
#   Using cached https://files.pythonhosted.org/packages/9a/41/220f49aaea88bc6fa6cba8d05ecf24676326156c23b991e80b3f2fc24c77/pickleshare-0.7.5-py2.py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/pickleshare-0.7.5-py2.py3-none-any.whl
# Collecting prometheus-client==0.6.0 (from -r data/requirements.txt (line 33))
#   Using cached https://files.pythonhosted.org/packages/4c/bd/b42db3ec90ffc6be805aad09c1cea4bb13a620d0cd4b21aaa44d13541d71/prometheus_client-0.6.0.tar.gz
# Collecting prompt-toolkit==2.0.9 (from -r data/requirements.txt (line 34))
#   Using cached https://files.pythonhosted.org/packages/f7/a7/9b1dd14ef45345f186ef69d175bdd2491c40ab1dfa4b2b3e4352df719ed7/prompt_toolkit-2.0.9-py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/prompt_toolkit-2.0.9-py3-none-any.whl
# Collecting ptyprocess==0.6.0 (from -r data/requirements.txt (line 35))
#   Using cached https://files.pythonhosted.org/packages/d1/29/605c2cc68a9992d18dada28206eeada56ea4bd07a239669da41674648b6f/ptyprocess-0.6.0-py2.py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/ptyprocess-0.6.0-py2.py3-none-any.whl
# Collecting Pygments==2.3.1 (from -r data/requirements.txt (line 36))
#   Using cached https://files.pythonhosted.org/packages/13/e5/6d710c9cf96c31ac82657bcfb441df328b22df8564d58d0c4cd62612674c/Pygments-2.3.1-py2.py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/Pygments-2.3.1-py2.py3-none-any.whl
# Collecting pymongo==3.7.2 (from -r data/requirements.txt (line 37))
#   Using cached https://files.pythonhosted.org/packages/d7/ac/d2e324c1f9bcf653fa106785371a16b4709506a35b04948655de8b961a85/pymongo-3.7.2-cp37-cp37m-macosx_10_9_x86_64.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/pymongo-3.7.2-cp37-cp37m-macosx_10_9_x86_64.whl
# Collecting pyrsistent==0.14.11 (from -r data/requirements.txt (line 38))
#   Using cached https://files.pythonhosted.org/packages/8c/46/4e93ab8a379d7efe93f20a0fb8a27bdfe88942cc954ab0210c3164e783e0/pyrsistent-0.14.11.tar.gz
# Collecting python-dateutil==2.8.0 (from -r data/requirements.txt (line 39))
#   Using cached https://files.pythonhosted.org/packages/41/17/c62faccbfbd163c7f57f3844689e3a78bae1f403648a6afb1d0866d87fbb/python_dateutil-2.8.0-py2.py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/python_dateutil-2.8.0-py2.py3-none-any.whl
# Collecting pyzmq==18.0.1 (from -r data/requirements.txt (line 40))
#   Using cached https://files.pythonhosted.org/packages/30/08/64b910e8f5e0285598a15a8d8f2f4d06a1367f0d145c7554fdd02d926272/pyzmq-18.0.1-cp37-cp37m-macosx_10_9_x86_64.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/pyzmq-18.0.1-cp37-cp37m-macosx_10_9_x86_64.whl
# Collecting qtconsole==4.4.3 (from -r data/requirements.txt (line 41))
#   Using cached https://files.pythonhosted.org/packages/e0/7a/8aefbc0ed078dec7951ac9a06dcd1869243ecd7bcbce26fa47bf5e469a8f/qtconsole-4.4.3-py2.py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/qtconsole-4.4.3-py2.py3-none-any.whl
# Collecting s3transfer==0.2.0 (from -r data/requirements.txt (line 42))
#   Using cached https://files.pythonhosted.org/packages/d7/de/5737f602e22073ecbded7a0c590707085e154e32b68d86545dcc31004c02/s3transfer-0.2.0-py2.py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/s3transfer-0.2.0-py2.py3-none-any.whl
# Collecting scikit-learn==0.20.3 (from -r data/requirements.txt (line 43))
#   Using cached https://files.pythonhosted.org/packages/bd/1a/5dc99dfa7e7bf2e1f22a07f440b61299148a42d13dee1d5153360313ed67/scikit_learn-0.20.3-cp37-cp37m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/scikit_learn-0.20.3-cp37-cp37m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl
# Collecting scipy==1.2.1 (from -r data/requirements.txt (line 44))
#   Using cached https://files.pythonhosted.org/packages/dd/6c/ccf7403d14f0ab0f20ce611696921f204f4ffce99a4fd383c892a6a7e9eb/scipy-1.2.1-cp37-cp37m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/scipy-1.2.1-cp37-cp37m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl
# Collecting Send2Trash==1.5.0 (from -r data/requirements.txt (line 45))
#   Using cached https://files.pythonhosted.org/packages/49/46/c3dc27481d1cc57b9385aff41c474ceb7714f7935b1247194adae45db714/Send2Trash-1.5.0-py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/Send2Trash-1.5.0-py3-none-any.whl
# Collecting simplejson==3.16.0 (from -r data/requirements.txt (line 46))
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/simplejson-3.16.0-cp37-cp37m-macosx_10_12_x86_64.whl
# Collecting six==1.12.0 (from -r data/requirements.txt (line 47))
#   Using cached https://files.pythonhosted.org/packages/73/fb/00a976f728d0d1fecfe898238ce23f502a721c0ac0ecfedb80e0d88c64e9/six-1.12.0-py2.py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/six-1.12.0-py2.py3-none-any.whl
# Collecting sklearn==0.0 (from -r data/requirements.txt (line 48))
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/sklearn-0.0-py2.py3-none-any.whl
# Collecting terminado==0.8.1 (from -r data/requirements.txt (line 49))
#   Using cached https://files.pythonhosted.org/packages/2e/20/a26211a24425923d46e1213b376a6ee60dc30bcdf1b0c345e2c3769deb1c/terminado-0.8.1-py2.py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/terminado-0.8.1-py2.py3-none-any.whl
# Collecting testpath==0.4.2 (from -r data/requirements.txt (line 50))
#   Using cached https://files.pythonhosted.org/packages/be/a4/162f9ebb6489421fe46dcca2ae420369edfee4b563c668d93cb4605d12ba/testpath-0.4.2-py2.py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/testpath-0.4.2-py2.py3-none-any.whl
# Collecting tornado==6.0.1 (from -r data/requirements.txt (line 51))
#   Using cached https://files.pythonhosted.org/packages/b1/7f/8109821ff9df1bf3519169e34646705c32ac13be6a4d51a79ed57f47686e/tornado-6.0.1.tar.gz
# Collecting traitlets==4.3.2 (from -r data/requirements.txt (line 52))
#   Using cached https://files.pythonhosted.org/packages/93/d6/abcb22de61d78e2fc3959c964628a5771e47e7cc60d53e9342e21ed6cc9a/traitlets-4.3.2-py2.py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/traitlets-4.3.2-py2.py3-none-any.whl
# Collecting urllib3==1.24.1 (from -r data/requirements.txt (line 53))
#   Using cached https://files.pythonhosted.org/packages/62/00/ee1d7de624db8ba7090d1226aebefab96a2c71cd5cfa7629d6ad3f61b79e/urllib3-1.24.1-py2.py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/urllib3-1.24.1-py2.py3-none-any.whl
# Collecting wcwidth==0.1.7 (from -r data/requirements.txt (line 54))
#   Using cached https://files.pythonhosted.org/packages/7e/9f/526a6947247599b084ee5232e4f9190a38f398d7300d866af3ab571a5bfe/wcwidth-0.1.7-py2.py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/wcwidth-0.1.7-py2.py3-none-any.whl
# Collecting webencodings==0.5.1 (from -r data/requirements.txt (line 55))
#   Using cached https://files.pythonhosted.org/packages/f4/24/2a3e3df732393fed8b3ebf2ec078f05546de641fe1b667ee316ec1dcf3b7/webencodings-0.5.1-py2.py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/webencodings-0.5.1-py2.py3-none-any.whl
# Collecting widgetsnbextension==3.4.2 (from -r data/requirements.txt (line 56))
#   Using cached https://files.pythonhosted.org/packages/8a/81/35789a3952afb48238289171728072d26d6e76649ddc8b3588657a2d78c1/widgetsnbextension-3.4.2-py2.py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/widgetsnbextension-3.4.2-py2.py3-none-any.whl
# Collecting setuptools>=18.5 (from ipython==7.3.0->-r data/requirements.txt (line 12))
#   Using cached https://files.pythonhosted.org/packages/d1/6a/4b2fcefd2ea0868810e92d519dacac1ddc64a2e53ba9e3422c3b62b378a6/setuptools-40.8.0-py2.py3-none-any.whl
#   Saved /Users/rick446/src/arborian-classes/data/wheelhouse/setuptools-40.8.0-py2.py3-none-any.whl
# Skipping appnope, due to already being wheel.
# Skipping attrs, due to already being wheel.
# Skipping backcall, due to already being wheel.
# Skipping bleach, due to already being wheel.
# Skipping boto3, due to already being wheel.
# Skipping botocore, due to already being wheel.
# Skipping decorator, due to already being wheel.
# Skipping defusedxml, due to already being wheel.
# Skipping docutils, due to already being wheel.
# Skipping entrypoints, due to already being wheel.
# Skipping ipykernel, due to already being wheel.
# Skipping ipython, due to already being wheel.
# Skipping ipython-genutils, due to already being wheel.
# Skipping ipywidgets, due to already being wheel.
# Skipping jedi, due to already being wheel.
# Skipping Jinja2, due to already being wheel.
# Skipping jmespath, due to already being wheel.
# Skipping jsonschema, due to already being wheel.
# Skipping jupyter, due to already being wheel.
# Skipping jupyter-client, due to already being wheel.
# Skipping jupyter-console, due to already being wheel.
# Skipping jupyter-core, due to already being wheel.
# Skipping MarkupSafe, due to already being wheel.
# Skipping mistune, due to already being wheel.
# Skipping nbconvert, due to already being wheel.
# Skipping nbformat, due to already being wheel.
# Skipping notebook, due to already being wheel.
# Skipping numpy, due to already being wheel.
# Skipping pandocfilters, due to already being wheel.
# Skipping parso, due to already being wheel.
# Skipping pexpect, due to already being wheel.
# Skipping pickleshare, due to already being wheel.
# Skipping prompt-toolkit, due to already being wheel.
# Skipping ptyprocess, due to already being wheel.
# Skipping Pygments, due to already being wheel.
# Skipping pymongo, due to already being wheel.
# Skipping python-dateutil, due to already being wheel.
# Skipping pyzmq, due to already being wheel.
# Skipping qtconsole, due to already being wheel.
# Skipping s3transfer, due to already being wheel.
# Skipping scikit-learn, due to already being wheel.
# Skipping scipy, due to already being wheel.
# Skipping Send2Trash, due to already being wheel.
# Skipping simplejson, due to already being wheel.
# Skipping six, due to already being wheel.
# Skipping sklearn, due to already being wheel.
# Skipping terminado, due to already being wheel.
# Skipping testpath, due to already being wheel.
# Skipping traitlets, due to already being wheel.
# Skipping urllib3, due to already being wheel.
# Skipping wcwidth, due to already being wheel.
# Skipping webencodings, due to already being wheel.
# Skipping widgetsnbextension, due to already being wheel.
# Skipping setuptools, due to already being wheel.
# Building wheels for collected packages: prometheus-client, pyrsistent, tornado
#   Building wheel for prometheus-client (setup.py): started
#   Building wheel for prometheus-client (setup.py): finished with status 'done'
#   Stored in directory: /Users/rick446/src/arborian-classes/data/wheelhouse
#   Building wheel for pyrsistent (setup.py): started
#   Building wheel for pyrsistent (setup.py): finished with status 'done'
#   Stored in directory: /Users/rick446/src/arborian-classes/data/wheelhouse
#   Building wheel for tornado (setup.py): started
#   Building wheel for tornado (setup.py): finished with status 'done'
#   Stored in directory: /Users/rick446/src/arborian-classes/data/wheelhouse
# Successfully built prometheus-client pyrsistent tornado

# %%
ls data/wheelhouse
# Out:
# Jinja2-2.10-py2.py3-none-any.whl
# MarkupSafe-1.1.1-cp37-cp37m-macosx_10_6_intel.whl
# Pygments-2.3.1-py2.py3-none-any.whl
# Send2Trash-1.5.0-py3-none-any.whl
# appnope-0.1.0-py2.py3-none-any.whl
# attrs-19.1.0-py2.py3-none-any.whl
# backcall-0.1.0-cp37-none-any.whl
# bleach-3.1.0-py2.py3-none-any.whl
# boto3-1.9.118-py2.py3-none-any.whl
# botocore-1.12.118-py2.py3-none-any.whl
# decorator-4.4.0-py2.py3-none-any.whl
# defusedxml-0.5.0-py2.py3-none-any.whl
# docutils-0.14-py3-none-any.whl
# entrypoints-0.3-py2.py3-none-any.whl
# ipykernel-5.1.0-py3-none-any.whl
# ipython-7.3.0-py3-none-any.whl
# ipython_genutils-0.2.0-py2.py3-none-any.whl
# ipywidgets-7.4.2-py2.py3-none-any.whl
# jedi-0.13.3-py2.py3-none-any.whl
# jmespath-0.9.4-py2.py3-none-any.whl
# jsonschema-3.0.1-py2.py3-none-any.whl
# jupyter-1.0.0-py2.py3-none-any.whl
# jupyter_client-5.2.4-py2.py3-none-any.whl
# jupyter_console-6.0.0-py2.py3-none-any.whl
# jupyter_core-4.4.0-py2.py3-none-any.whl
# mistune-0.8.4-py2.py3-none-any.whl
# nbconvert-5.4.1-py2.py3-none-any.whl
# nbformat-4.4.0-py2.py3-none-any.whl
# notebook-5.7.6-py2.py3-none-any.whl
# numpy-1.16.2-cp37-cp37m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl
# pandocfilters-1.4.2-cp37-none-any.whl
# parso-0.3.4-py2.py3-none-any.whl
# pexpect-4.6.0-py2.py3-none-any.whl
# pickleshare-0.7.5-py2.py3-none-any.whl
# prometheus_client-0.6.0-py3-none-any.whl
# prompt_toolkit-2.0.9-py3-none-any.whl
# ptyprocess-0.6.0-py2.py3-none-any.whl
# pymongo-3.7.2-cp37-cp37m-macosx_10_9_x86_64.whl
# pyrsistent-0.14.11-cp37-cp37m-macosx_10_14_x86_64.whl
# python_dateutil-2.8.0-py2.py3-none-any.whl
# pyzmq-18.0.1-cp37-cp37m-macosx_10_9_x86_64.whl
# qtconsole-4.4.3-py2.py3-none-any.whl
# s3transfer-0.2.0-py2.py3-none-any.whl
# scikit_learn-0.20.3-cp37-cp37m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl
# scipy-1.2.1-cp37-cp37m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl
# setuptools-40.8.0-py2.py3-none-any.whl
# simplejson-3.16.0-cp37-cp37m-macosx_10_12_x86_64.whl
# six-1.12.0-py2.py3-none-any.whl
# sklearn-0.0-py2.py3-none-any.whl
# terminado-0.8.1-py2.py3-none-any.whl
# testpath-0.4.2-py2.py3-none-any.whl
# tornado-6.0.1-cp37-cp37m-macosx_10_14_x86_64.whl
# traitlets-4.3.2-py2.py3-none-any.whl
# urllib3-1.24.1-py2.py3-none-any.whl
# wcwidth-0.1.7-py2.py3-none-any.whl
# webencodings-0.5.1-py2.py3-none-any.whl
# widgetsnbextension-3.4.2-py2.py3-none-any.whl

# %% [markdown]
# Now we can distribute the `data/wheelhouse` directory with our project and install everything from the wheelhouse and not fetch from PyPI:

# %%
# %%bash
# set -e
# source data/env-folder-2/bin/activate
# pip install --no-index -f data/wheelhouse -r data/requirements.txt
# Out:
# Looking in links: data/wheelhouse
# Collecting appnope==0.1.0 (from -r data/requirements.txt (line 1))
# Collecting attrs==19.1.0 (from -r data/requirements.txt (line 2))
# Collecting backcall==0.1.0 (from -r data/requirements.txt (line 3))
# Collecting bleach==3.1.0 (from -r data/requirements.txt (line 4))
# Collecting boto3==1.9.118 (from -r data/requirements.txt (line 5))
# Collecting botocore==1.12.118 (from -r data/requirements.txt (line 6))
# Collecting decorator==4.4.0 (from -r data/requirements.txt (line 7))
# Collecting defusedxml==0.5.0 (from -r data/requirements.txt (line 8))
# Collecting docutils==0.14 (from -r data/requirements.txt (line 9))
# Collecting entrypoints==0.3 (from -r data/requirements.txt (line 10))
# Collecting ipykernel==5.1.0 (from -r data/requirements.txt (line 11))
# Collecting ipython==7.3.0 (from -r data/requirements.txt (line 12))
# Collecting ipython-genutils==0.2.0 (from -r data/requirements.txt (line 13))
# Collecting ipywidgets==7.4.2 (from -r data/requirements.txt (line 14))
# Collecting jedi==0.13.3 (from -r data/requirements.txt (line 15))
# Collecting Jinja2==2.10 (from -r data/requirements.txt (line 16))
# Collecting jmespath==0.9.4 (from -r data/requirements.txt (line 17))
# Collecting jsonschema==3.0.1 (from -r data/requirements.txt (line 18))
# Collecting jupyter==1.0.0 (from -r data/requirements.txt (line 19))
# Collecting jupyter-client==5.2.4 (from -r data/requirements.txt (line 20))
# Collecting jupyter-console==6.0.0 (from -r data/requirements.txt (line 21))
# Collecting jupyter-core==4.4.0 (from -r data/requirements.txt (line 22))
# Collecting MarkupSafe==1.1.1 (from -r data/requirements.txt (line 23))
# Collecting mistune==0.8.4 (from -r data/requirements.txt (line 24))
# Collecting nbconvert==5.4.1 (from -r data/requirements.txt (line 25))
# Collecting nbformat==4.4.0 (from -r data/requirements.txt (line 26))
# Collecting notebook==5.7.6 (from -r data/requirements.txt (line 27))
# Requirement already satisfied: numpy==1.16.2 in /Users/rick446/src/arborian-classes/data/env-folder-2/lib/python3.7/site-packages (from -r data/requirements.txt (line 28)) (1.16.2)
# Collecting pandocfilters==1.4.2 (from -r data/requirements.txt (line 29))
# Collecting parso==0.3.4 (from -r data/requirements.txt (line 30))
# Collecting pexpect==4.6.0 (from -r data/requirements.txt (line 31))
# Collecting pickleshare==0.7.5 (from -r data/requirements.txt (line 32))
# Collecting prometheus-client==0.6.0 (from -r data/requirements.txt (line 33))
# Collecting prompt-toolkit==2.0.9 (from -r data/requirements.txt (line 34))
# Collecting ptyprocess==0.6.0 (from -r data/requirements.txt (line 35))
# Collecting Pygments==2.3.1 (from -r data/requirements.txt (line 36))
# Collecting pymongo==3.7.2 (from -r data/requirements.txt (line 37))
# Collecting pyrsistent==0.14.11 (from -r data/requirements.txt (line 38))
# Collecting python-dateutil==2.8.0 (from -r data/requirements.txt (line 39))
# Collecting pyzmq==18.0.1 (from -r data/requirements.txt (line 40))
# Collecting qtconsole==4.4.3 (from -r data/requirements.txt (line 41))
# Collecting s3transfer==0.2.0 (from -r data/requirements.txt (line 42))
# Collecting scikit-learn==0.20.3 (from -r data/requirements.txt (line 43))
# Collecting scipy==1.2.1 (from -r data/requirements.txt (line 44))
# Collecting Send2Trash==1.5.0 (from -r data/requirements.txt (line 45))
# Collecting simplejson==3.16.0 (from -r data/requirements.txt (line 46))
# Collecting six==1.12.0 (from -r data/requirements.txt (line 47))
# Collecting sklearn==0.0 (from -r data/requirements.txt (line 48))
# Collecting terminado==0.8.1 (from -r data/requirements.txt (line 49))
# Collecting testpath==0.4.2 (from -r data/requirements.txt (line 50))
# Collecting tornado==6.0.1 (from -r data/requirements.txt (line 51))
# Collecting traitlets==4.3.2 (from -r data/requirements.txt (line 52))
# Collecting urllib3==1.24.1 (from -r data/requirements.txt (line 53))
# Collecting wcwidth==0.1.7 (from -r data/requirements.txt (line 54))
# Collecting webencodings==0.5.1 (from -r data/requirements.txt (line 55))
# Collecting widgetsnbextension==3.4.2 (from -r data/requirements.txt (line 56))
# Requirement already satisfied: setuptools>=18.5 in /Users/rick446/src/arborian-classes/data/env-folder-2/lib/python3.7/site-packages (from ipython==7.3.0->-r data/requirements.txt (line 12)) (40.6.2)
# Installing collected packages: appnope, attrs, backcall, webencodings, six, bleach, urllib3, python-dateutil, jmespath, docutils, botocore, s3transfer, boto3, decorator, defusedxml, entrypoints, ipython-genutils, traitlets, pyzmq, jupyter-core, tornado, jupyter-client, parso, jedi, wcwidth, prompt-toolkit, Pygments, pickleshare, ptyprocess, pexpect, ipython, ipykernel, prometheus-client, pyrsistent, jsonschema, nbformat, terminado, MarkupSafe, Jinja2, Send2Trash, pandocfilters, mistune, testpath, nbconvert, notebook, widgetsnbextension, ipywidgets, jupyter-console, qtconsole, jupyter, pymongo, scipy, scikit-learn, simplejson, sklearn
# Successfully installed Jinja2-2.10 MarkupSafe-1.1.1 Pygments-2.3.1 Send2Trash-1.5.0 appnope-0.1.0 attrs-19.1.0 backcall-0.1.0 bleach-3.1.0 boto3-1.9.118 botocore-1.12.118 decorator-4.4.0 defusedxml-0.5.0 docutils-0.14 entrypoints-0.3 ipykernel-5.1.0 ipython-7.3.0 ipython-genutils-0.2.0 ipywidgets-7.4.2 jedi-0.13.3 jmespath-0.9.4 jsonschema-3.0.1 jupyter-1.0.0 jupyter-client-5.2.4 jupyter-console-6.0.0 jupyter-core-4.4.0 mistune-0.8.4 nbconvert-5.4.1 nbformat-4.4.0 notebook-5.7.6 pandocfilters-1.4.2 parso-0.3.4 pexpect-4.6.0 pickleshare-0.7.5 prometheus-client-0.6.0 prompt-toolkit-2.0.9 ptyprocess-0.6.0 pymongo-3.7.2 pyrsistent-0.14.11 python-dateutil-2.8.0 pyzmq-18.0.1 qtconsole-4.4.3 s3transfer-0.2.0 scikit-learn-0.20.3 scipy-1.2.1 simplejson-3.16.0 six-1.12.0 sklearn-0.0 terminado-0.8.1 testpath-0.4.2 tornado-6.0.1 traitlets-4.3.2 urllib3-1.24.1 wcwidth-0.1.7 webencodings-0.5.1 widgetsnbextension-3.4.2

# %% [markdown]
# # Cleaning up virtualenvs
#
# Since a virtualenv is just a directory, we can 'clean it up' by removing the directory:

# %%
# !rm -r data/env-folder data/env-folder-2 data/wheelhouse data/requirements.txt

# %% [markdown]
# # Lab
#
# Open [virtualenv lab][virtualenv-lab]
#
# [virtualenv-lab]: ./virtualenv-lab.ipynb
