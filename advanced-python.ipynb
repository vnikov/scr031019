# %% [markdown]
# # While we are waiting
#
# - Ensure you register your attendance on the sign-in sheet
# - Download the [courseware][courseware] from **http://bit.ly/advanced-python**
# - Ensure you have completed the [setup instructions][setup]
#
# [setup]: ./setup-anaconda.html
# [courseware]: http://bit.ly/advanced-python

# %% [markdown]
# # Advanced Python
#
# Rick Copeland<br/>
# rick@arborian.com<br/>
#
# Schedule
#
# Class times: 09:00 - 04:30
#
# Lunch: 12:00 - 1:00
#
# https://bit.ly/advanced-python
#
# In addition to labs, breaks every ~60-90min

# %% [markdown]
# # About You and Me
# * What is your job title/what do you do?
# * Python experience? Other languages?
# * What do you want to get out of the course? (Particular topics?)

# %% [markdown]
# # (rough) Course Outline and Schedule
#
# ## Day 1
#
# - [Jupyter, briefly][jupyter]
# - [Core Python Review (core syntax, data types)][core-syntax]
# - Advanced Python Syntax
#     - [Iteratables, Iterators, and Generators][iteration]
#     - [Advanced Generators: Pipelines and Coroutines][advanced-generators]
#     - [Asynchronous IO][asyncio]
# - Advanced OOP
#     - [Metaclasses, Class Decorators, and Descriptors][advanced-oop]
#
# ## Day 2
#
# - [Virtual Environments][virtualenv]
# - [Packaging Projects for Distribution][packaging]
# - Network Programming
#     - [Socket Programming][socket]
#     - [Consuming APIs Using Requests][requests]
#     - [Basic web server programming: WSGI][wsgi]
#     - [Handling Email][email]
#     - [Parsing HTML and XML][sgml]
# - Database Programming
#     - [Integrating with relational databases][dbapi]
#     - [Integrating with MongoDB][pymongo]
#
# ## Day 3
#
# - Web Programming
#     - [Flask APIs][flask-api]
#     - [Flask UIs][flask-ui]
#     - [Flask SQLAlchemy][flask-sqlalchemy]
#     - [Flask PyMongo][flask-pymongo]
# - Distributed Programming
#     - [Introduction to Celery][celery]
#     - [pycos][pycos]
#     - [Dispy][dispy]
#
# ## Additional Topics (as time permits)
#
# - [Advanced Data Types][advanced-data-types]
# - [Functional Programming][functional]
# - [Closures and Decorators][closures]
# - [NumPy][numpy] and [SciPy][scipy] for Numerical and Scientific Processing
# - [Pandas and Data Integration][pandas]
#
#
#
# [jupyter]: ./jupyter.ipynb
# [core-syntax]: ./core-syntax.ipynb
# [iteration]: ./iteration.ipynb
# [advanced-generators]: ./advanced-generators.ipynb
# [asyncio]: ./asyncio.ipynb
# [advanced-oop]: ./advanced-oop.ipynb
# [virtualenv]: ./virtualenv.ipynb
# [packaging]: ./packaging.ipynb
# [socket]: ./socket.ipynb
# [requests]: ./requests.ipynb
# [wsgi]: ./wsgi.ipynb
# [email]: ./email.ipynb
# [sgml]: ./sgml.ipynb
# [dbapi]: ./dbapi.ipynb
# [pymongo]: ./pymongo.ipynb
# [flask-api]: ./flask-api.ipynb
# [flask-ui]: ./flask-ui.ipynb
# [flask-sqlalchemy]: ./flask-sqlalchemy.ipynb
# [flask-pymongo]: ./flask-pymongo.ipynb
# [celery]: ./celery.ipynb
# [dispy]: ./dispy.ipynb
# [pycos]: ./pycos.ipynb
#
# [advanced-data-types]: ./advanced-data-types.ipynb
# [functional]: ./functional.ipynb
# [closures]: ./closures.ipynb
# [numpy]: ./numpy.ipynb
# [scipy]: ./scipy.ipynb
# [pandas]: ./pandas.ipynb
