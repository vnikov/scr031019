# %% [markdown]
# # Packaging Projects for Distribution
#
# - Creating a basic Python project with `setup.py` and `setup.cfg`
# - Specifying dependencies
# - Activating projects in a virtualenv with `setup.py develop`
# - Distributing data with your project
# - Using entry points to create console scripts
# - Uploading source distributions to PyPI

# %% [markdown]
# # First, some terminology...
#
# - a Python **module** is typically a single file ending in `.py` located somewhere along `sys.path` that you can use with the Python `import` statement
# - a Python **package** is a folder located somewhere along `sys.path` containing a "magic" file `__init__.py` which can also be imported. If you import a package, Python is actually importing the `__init__.py` *module* in that *package*. You can also import modules or subpackages from a package.
# - a Python **project** is a unit of distribution of Python code (it's something you can `pip install`)

# %% [markdown]
# # Creating a basic Python project with `setup.py` and `setup.cfg`
#
# To create a project for distribution, you'll need to create a directory with:
#
# - one or more Python packages to distribute
# - a `setup.py` file
# - (optionally) a `setup.cfg` file

# %%
# %%file data/MyProject/mypackage/__init__.py
print('This is the __init__ file for mypackage')

# %%
# %%file data/MyProject/mypackage/mymodule.py
print('This is mymodule')


def greet(name):
    print(f'Hello, {name}!')

# %% [markdown]
# For this demo, we'll use `setup.cfg` to provide metadata for our project, so we only need a minimal setup.py:

# %%
# %%file data/MyProject/setup.py
from setuptools import setup


setup()
# Out:
# Writing data/MyProject/setup.py

# %% [markdown]
# We can create the `setup.cfg` file to specify how `setuptools` will build and distribute our project:

# %%
# %%file data/MyProject/setup.cfg
# [metadata]
# name = MyProject
# url = file:///
# author = Some Person
# author_email = somebody@example.com
# version = 0.1
# description = This should be a short description of our project
# long_description = file: README.md
# classifiers =
#     Programming Language :: Python :: 3
#     Programming Language :: Python :: 3.7
# keywords = test, class
# Out:
# Writing data/MyProject/setup.cfg

# %% [markdown]
# It's always nice to provide a README as well:

# %%
# %%file data/MyProject/README.md
# # MyProject
#
# This project is a test setuptools project.
# Out:
# Writing data/MyProject/README.md

# %% [markdown]
# ## Creating a source distribution
#
# The entry point for all our project management commands is `setup.py`.
#
# We can create a simple source distribution of our project by calling `python setup.py sdist`:

# %%
# %%bash
# cd data/MyProject
# python setup.py sdist
# Out:
# running sdist
# running egg_info
# creating MyProject.egg-info
# writing MyProject.egg-info/PKG-INFO
# writing dependency_links to MyProject.egg-info/dependency_links.txt
# writing top-level names to MyProject.egg-info/top_level.txt
# writing manifest file 'MyProject.egg-info/SOURCES.txt'
# reading manifest file 'MyProject.egg-info/SOURCES.txt'
# writing manifest file 'MyProject.egg-info/SOURCES.txt'
# running check
# creating MyProject-0.1
# creating MyProject-0.1/MyProject.egg-info
# copying files to MyProject-0.1...
# copying README.md -> MyProject-0.1
# copying setup.cfg -> MyProject-0.1
# copying setup.py -> MyProject-0.1
# copying MyProject.egg-info/PKG-INFO -> MyProject-0.1/MyProject.egg-info
# copying MyProject.egg-info/SOURCES.txt -> MyProject-0.1/MyProject.egg-info
# copying MyProject.egg-info/dependency_links.txt -> MyProject-0.1/MyProject.egg-info
# copying MyProject.egg-info/top_level.txt -> MyProject-0.1/MyProject.egg-info
# Writing MyProject-0.1/setup.cfg
# creating dist
# Creating tar archive
# removing 'MyProject-0.1' (and everything under it)

# %%
# !tar tzf data/MyProject/dist/MyProject-0.1.tar.gz
# Out:
# MyProject-0.1/
# MyProject-0.1/MyProject.egg-info/
# MyProject-0.1/MyProject.egg-info/PKG-INFO
# MyProject-0.1/MyProject.egg-info/SOURCES.txt
# MyProject-0.1/MyProject.egg-info/dependency_links.txt
# MyProject-0.1/MyProject.egg-info/top_level.txt
# MyProject-0.1/PKG-INFO
# MyProject-0.1/README.md
# MyProject-0.1/setup.cfg
# MyProject-0.1/setup.py

# %% [markdown]
# ## Adding our packages
#
# So we have an empty project (no packages/modules). We need to tell setuptools to actually include our package explicitly:

# %%
# %%file data/MyProject/setup.cfg
# [metadata]
# name = MyProject
# url = file:///
# author = Some Person
# author_email = somebody@example.com
# version = 0.1
# description = This should be a short description of our project
# long_description = file: README.md
# classifiers =
#     Programming Language :: Python :: 3
#     Programming Language :: Python :: 3.7
# keywords = test, class
#
# [options]
# packages = mypackage
# Out:
# Overwriting data/MyProject/setup.cfg

# %%
# %%bash
# cd data/MyProject
# python setup.py sdist
# Out:
# running sdist
# running egg_info
# writing MyProject.egg-info/PKG-INFO
# writing dependency_links to MyProject.egg-info/dependency_links.txt
# writing top-level names to MyProject.egg-info/top_level.txt
# reading manifest file 'MyProject.egg-info/SOURCES.txt'
# writing manifest file 'MyProject.egg-info/SOURCES.txt'
# running check
# creating MyProject-0.1
# creating MyProject-0.1/MyProject.egg-info
# creating MyProject-0.1/mypackage
# copying files to MyProject-0.1...
# copying README.md -> MyProject-0.1
# copying setup.cfg -> MyProject-0.1
# copying setup.py -> MyProject-0.1
# copying MyProject.egg-info/PKG-INFO -> MyProject-0.1/MyProject.egg-info
# copying MyProject.egg-info/SOURCES.txt -> MyProject-0.1/MyProject.egg-info
# copying MyProject.egg-info/dependency_links.txt -> MyProject-0.1/MyProject.egg-info
# copying MyProject.egg-info/top_level.txt -> MyProject-0.1/MyProject.egg-info
# copying mypackage/__init__.py -> MyProject-0.1/mypackage
# copying mypackage/mymodule.py -> MyProject-0.1/mypackage
# Writing MyProject-0.1/setup.cfg
# Creating tar archive
# removing 'MyProject-0.1' (and everything under it)

# %% [markdown]
# ## Specifying dependencies
#
# We can tell setuptools that we depend on particular versions (or version ranges) of other packages with an `install_requires` option:

# %%
# %%file data/MyProject/setup.cfg
# [metadata]
# name = MyProject
# url = file:///
# author = Some Person
# author_email = somebody@example.com
# version = 0.1
# description = This should be a short description of our project
# long_description = file: README.md
# classifiers =
#     Programming Language :: Python :: 3
#     Programming Language :: Python :: 3.7
# keywords = test, class
#
# [options]
# packages = mypackage
# install_requires =
#     jupyter
#     flask
#     numpy>=1.16.0<1.17
# Out:
# Overwriting data/MyProject/setup.cfg

# %%
# %%bash
# cd data/MyProject
# python setup.py sdist
# Out:
# running sdist
# running egg_info
# writing MyProject.egg-info/PKG-INFO
# writing dependency_links to MyProject.egg-info/dependency_links.txt
# writing requirements to MyProject.egg-info/requires.txt
# writing top-level names to MyProject.egg-info/top_level.txt
# reading manifest file 'MyProject.egg-info/SOURCES.txt'
# writing manifest file 'MyProject.egg-info/SOURCES.txt'
# running check
# creating MyProject-0.1
# creating MyProject-0.1/MyProject.egg-info
# creating MyProject-0.1/mypackage
# copying files to MyProject-0.1...
# copying README.md -> MyProject-0.1
# copying setup.cfg -> MyProject-0.1
# copying setup.py -> MyProject-0.1
# copying MyProject.egg-info/PKG-INFO -> MyProject-0.1/MyProject.egg-info
# copying MyProject.egg-info/SOURCES.txt -> MyProject-0.1/MyProject.egg-info
# copying MyProject.egg-info/dependency_links.txt -> MyProject-0.1/MyProject.egg-info
# copying MyProject.egg-info/requires.txt -> MyProject-0.1/MyProject.egg-info
# copying MyProject.egg-info/top_level.txt -> MyProject-0.1/MyProject.egg-info
# copying mypackage/__init__.py -> MyProject-0.1/mypackage
# copying mypackage/mymodule.py -> MyProject-0.1/mypackage
# Writing MyProject-0.1/setup.cfg
# Creating tar archive
# removing 'MyProject-0.1' (and everything under it)

# %% [markdown]
# # Activating projects using `setup.py develop`
#
# When we're developing our project, we probably want its packages to be importable as though it were 'installed' in our virtualenv. To do this, we can invoke `setup.py` with the `develop` option.
#
# This creates a `MyProject.egg-link` file in a location along `sys.path` which makes your packages importable from anwhere that uses the virtualenv.

# %%
# %%bash
# cd data/MyProject
# python -m venv env
# source env/bin/activate
# python setup.py develop
# Out:
# running develop
# running egg_info
# writing MyProject.egg-info/PKG-INFO
# writing dependency_links to MyProject.egg-info/dependency_links.txt
# writing requirements to MyProject.egg-info/requires.txt
# writing top-level names to MyProject.egg-info/top_level.txt
# reading manifest file 'MyProject.egg-info/SOURCES.txt'
# writing manifest file 'MyProject.egg-info/SOURCES.txt'
# running build_ext
# Creating /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/MyProject.egg-link (link to .)
# Adding MyProject 0.1 to easy-install.pth file
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject
# Processing dependencies for MyProject==0.1
# Searching for numpy>=1.16.0<1.17
# Reading https://pypi.org/simple/numpy/
# Downloading https://files.pythonhosted.org/packages/a6/6f/cb20ccd8f0f8581e0e090775c0e3c3e335b037818416e6fa945d924397d2/numpy-1.16.2-cp37-cp37m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl#sha256=80a41edf64a3626e729a62df7dd278474fc1726836552b67a8c6396fd7e86760
# Best match: numpy 1.16.2
# Processing numpy-1.16.2-cp37-cp37m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl
# Installing numpy-1.16.2-cp37-cp37m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# Adding numpy 1.16.2 to easy-install.pth file
# Installing f2py script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
# Installing f2py3 script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
# Installing f2py3.7 script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/numpy-1.16.2-py3.7-macosx-10.14-x86_64.egg
# Searching for flask
# Reading https://pypi.org/simple/flask/
# Downloading https://files.pythonhosted.org/packages/7f/e7/08578774ed4536d3242b14dacb4696386634607af824ea997202cd0edb4b/Flask-1.0.2-py2.py3-none-any.whl#sha256=a080b744b7e345ccfcbc77954861cb05b3c63786e93f2b3875e0913d44b43f05
# Best match: Flask 1.0.2
# Processing Flask-1.0.2-py2.py3-none-any.whl
# Installing Flask-1.0.2-py2.py3-none-any.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# writing requirements to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/Flask-1.0.2-py3.7.egg/EGG-INFO/requires.txt
# Adding Flask 1.0.2 to easy-install.pth file
# Installing flask script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/Flask-1.0.2-py3.7.egg
# Searching for jupyter
# Reading https://pypi.org/simple/jupyter/
# Downloading https://files.pythonhosted.org/packages/83/df/0f5dd132200728a86190397e1ea87cd76244e42d39ec5e88efd25b2abd7e/jupyter-1.0.0-py2.py3-none-any.whl#sha256=5b290f93b98ffbc21c0c7e749f054b3267782166d72fa5e3ed1ed4eaf34a2b78
# Best match: jupyter 1.0.0
# Processing jupyter-1.0.0-py2.py3-none-any.whl
# Installing jupyter-1.0.0-py2.py3-none-any.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# writing requirements to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/jupyter-1.0.0-py3.7.egg/EGG-INFO/requires.txt
# Adding jupyter 1.0.0 to easy-install.pth file
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/jupyter-1.0.0-py3.7.egg
# Searching for itsdangerous>=0.24
# Reading https://pypi.org/simple/itsdangerous/
# Downloading https://files.pythonhosted.org/packages/76/ae/44b03b253d6fade317f32c24d100b3b35c2239807046a4c953c7b89fa49e/itsdangerous-1.1.0-py2.py3-none-any.whl#sha256=b12271b2047cb23eeb98c8b5622e2e5c5e9abd9784a153e9d8ef9cb4dd09d749
# Best match: itsdangerous 1.1.0
# Processing itsdangerous-1.1.0-py2.py3-none-any.whl
# Installing itsdangerous-1.1.0-py2.py3-none-any.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# Adding itsdangerous 1.1.0 to easy-install.pth file
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/itsdangerous-1.1.0-py3.7.egg
# Searching for click>=5.1
# Reading https://pypi.org/simple/click/
# Downloading https://files.pythonhosted.org/packages/fa/37/45185cb5abbc30d7257104c434fe0b07e5a195a6847506c074527aa599ec/Click-7.0-py2.py3-none-any.whl#sha256=2335065e6395b9e67ca716de5f7526736bfa6ceead690adf616d925bdc622b13
# Best match: Click 7.0
# Processing Click-7.0-py2.py3-none-any.whl
# Installing Click-7.0-py2.py3-none-any.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# Adding Click 7.0 to easy-install.pth file
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/Click-7.0-py3.7.egg
# Searching for Werkzeug>=0.14
# Reading https://pypi.org/simple/Werkzeug/
# Downloading https://files.pythonhosted.org/packages/24/4d/2fc4e872fbaaf44cc3fd5a9cd42fda7e57c031f08e28c9f35689e8b43198/Werkzeug-0.15.1-py2.py3-none-any.whl#sha256=96da23fa8ccecbc3ae832a83df5c722c11547d021637faacb0bec4dd2f4666c8
# Best match: Werkzeug 0.15.1
# Processing Werkzeug-0.15.1-py2.py3-none-any.whl
# Installing Werkzeug-0.15.1-py2.py3-none-any.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# writing requirements to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/Werkzeug-0.15.1-py3.7.egg/EGG-INFO/requires.txt
# Adding Werkzeug 0.15.1 to easy-install.pth file
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/Werkzeug-0.15.1-py3.7.egg
# Searching for Jinja2>=2.10
# Reading https://pypi.org/simple/Jinja2/
# Downloading https://files.pythonhosted.org/packages/7f/ff/ae64bacdfc95f27a016a7bed8e8686763ba4d277a78ca76f32659220a731/Jinja2-2.10-py2.py3-none-any.whl#sha256=74c935a1b8bb9a3947c50a54766a969d4846290e1e788ea44c1392163723c3bd
# Best match: Jinja2 2.10
# Processing Jinja2-2.10-py2.py3-none-any.whl
# Installing Jinja2-2.10-py2.py3-none-any.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# writing requirements to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/Jinja2-2.10-py3.7.egg/EGG-INFO/requires.txt
# Adding Jinja2 2.10 to easy-install.pth file
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/Jinja2-2.10-py3.7.egg
# Searching for qtconsole
# Reading https://pypi.org/simple/qtconsole/
# Downloading https://files.pythonhosted.org/packages/e0/7a/8aefbc0ed078dec7951ac9a06dcd1869243ecd7bcbce26fa47bf5e469a8f/qtconsole-4.4.3-py2.py3-none-any.whl#sha256=1ac4a65e81a27b0838330a6d351c2f8435d4013d98a95373e8a41119b2968390
# Best match: qtconsole 4.4.3
# Processing qtconsole-4.4.3-py2.py3-none-any.whl
# Installing qtconsole-4.4.3-py2.py3-none-any.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# writing requirements to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/qtconsole-4.4.3-py3.7.egg/EGG-INFO/requires.txt
# Adding qtconsole 4.4.3 to easy-install.pth file
# Installing jupyter-qtconsole script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/qtconsole-4.4.3-py3.7.egg
# Searching for notebook
# Reading https://pypi.org/simple/notebook/
# Downloading https://files.pythonhosted.org/packages/0a/d8/4e9521354ed3d730ba6d8a5af440b66c73245ef46be706e51bead71afc21/notebook-5.7.6-py2.py3-none-any.whl#sha256=cc027a62be0f7756e0ef3d2d98458c4d7f4b3566449fb1a05891207f5bd9a1bf
# Best match: notebook 5.7.6
# Processing notebook-5.7.6-py2.py3-none-any.whl
# Installing notebook-5.7.6-py2.py3-none-any.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# writing requirements to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/notebook-5.7.6-py3.7.egg/EGG-INFO/requires.txt
# Adding notebook 5.7.6 to easy-install.pth file
# Installing jupyter-bundlerextension script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
# Installing jupyter-nbextension script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
# Installing jupyter-notebook script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
# Installing jupyter-serverextension script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/notebook-5.7.6-py3.7.egg
# Searching for nbconvert
# Reading https://pypi.org/simple/nbconvert/
# Downloading https://files.pythonhosted.org/packages/b8/39/1e67fea74dc9577cc49f9863fe3ec824e525d1304ab6027d95a94cd586f5/nbconvert-5.4.1-py2.py3-none-any.whl#sha256=5de8fb2284422272a1d45abc77c07b888127550a6d602ce619592a2b08a474ff
# Best match: nbconvert 5.4.1
# Processing nbconvert-5.4.1-py2.py3-none-any.whl
# Installing nbconvert-5.4.1-py2.py3-none-any.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# writing requirements to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/nbconvert-5.4.1-py3.7.egg/EGG-INFO/requires.txt
# Adding nbconvert 5.4.1 to easy-install.pth file
# Installing jupyter-nbconvert script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/nbconvert-5.4.1-py3.7.egg
# Searching for jupyter-console
# Reading https://pypi.org/simple/jupyter-console/
# Downloading https://files.pythonhosted.org/packages/cb/ee/6374ae8c21b7d0847f9c3722dcdfac986b8e54fa9ad9ea66e1eb6320d2b8/jupyter_console-6.0.0-py2.py3-none-any.whl#sha256=cc80a97a5c389cbd30252ffb5ce7cefd4b66bde98219edd16bf5cb6f84bb3568
# Best match: jupyter-console 6.0.0
# Processing jupyter_console-6.0.0-py2.py3-none-any.whl
# Installing jupyter_console-6.0.0-py2.py3-none-any.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# writing requirements to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/jupyter_console-6.0.0-py3.7.egg/EGG-INFO/requires.txt
# Adding jupyter-console 6.0.0 to easy-install.pth file
# Installing jupyter-console script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/jupyter_console-6.0.0-py3.7.egg
# Searching for ipywidgets
# Reading https://pypi.org/simple/ipywidgets/
# Downloading https://files.pythonhosted.org/packages/30/9a/a008c7b1183fac9e52066d80a379b3c64eab535bd9d86cdc29a0b766fd82/ipywidgets-7.4.2-py2.py3-none-any.whl#sha256=0f2b5cde9f272cb49d52f3f0889fdd1a7ae1e74f37b48dac35a83152780d2b7b
# Best match: ipywidgets 7.4.2
# Processing ipywidgets-7.4.2-py2.py3-none-any.whl
# Installing ipywidgets-7.4.2-py2.py3-none-any.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# writing requirements to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/ipywidgets-7.4.2-py3.7.egg/EGG-INFO/requires.txt
# Adding ipywidgets 7.4.2 to easy-install.pth file
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/ipywidgets-7.4.2-py3.7.egg
# Searching for ipykernel
# Reading https://pypi.org/simple/ipykernel/
# Downloading https://files.pythonhosted.org/packages/d8/b0/f0be5c5ab335196f5cce96e5b889a4fcf5bfe462eb0acc05cd7e2caf65eb/ipykernel-5.1.0-py3-none-any.whl#sha256=0aeb7ec277ac42cc2b59ae3d08b10909b2ec161dc6908096210527162b53675d
# Best match: ipykernel 5.1.0
# Processing ipykernel-5.1.0-py3-none-any.whl
# Installing ipykernel-5.1.0-py3-none-any.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# writing requirements to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/ipykernel-5.1.0-py3.7.egg/EGG-INFO/requires.txt
# Adding ipykernel 5.1.0 to easy-install.pth file
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/ipykernel-5.1.0-py3.7.egg
# Searching for MarkupSafe>=0.23
# Reading https://pypi.org/simple/MarkupSafe/
# Downloading https://files.pythonhosted.org/packages/ce/c6/f000f1af136ef74e4a95e33785921c73595c5390403f102e9b231b065b7a/MarkupSafe-1.1.1-cp37-cp37m-macosx_10_6_intel.whl#sha256=8defac2f2ccd6805ebf65f5eeb132adcf2ab57aa11fdf4c0dd5169a004710e7d
# Best match: MarkupSafe 1.1.1
# Processing MarkupSafe-1.1.1-cp37-cp37m-macosx_10_6_intel.whl
# Installing MarkupSafe-1.1.1-cp37-cp37m-macosx_10_6_intel.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# Adding MarkupSafe 1.1.1 to easy-install.pth file
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/MarkupSafe-1.1.1-py3.7-macosx-10.14-x86_64.egg
# Searching for traitlets
# Reading https://pypi.org/simple/traitlets/
# Downloading https://files.pythonhosted.org/packages/93/d6/abcb22de61d78e2fc3959c964628a5771e47e7cc60d53e9342e21ed6cc9a/traitlets-4.3.2-py2.py3-none-any.whl#sha256=c6cb5e6f57c5a9bdaa40fa71ce7b4af30298fbab9ece9815b5d995ab6217c7d9
# Best match: traitlets 4.3.2
# Processing traitlets-4.3.2-py2.py3-none-any.whl
# Installing traitlets-4.3.2-py2.py3-none-any.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# writing requirements to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/traitlets-4.3.2-py3.7.egg/EGG-INFO/requires.txt
# Adding traitlets 4.3.2 to easy-install.pth file
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/traitlets-4.3.2-py3.7.egg
# Searching for pygments
# Reading https://pypi.org/simple/pygments/
# Downloading https://files.pythonhosted.org/packages/13/e5/6d710c9cf96c31ac82657bcfb441df328b22df8564d58d0c4cd62612674c/Pygments-2.3.1-py2.py3-none-any.whl#sha256=e8218dd399a61674745138520d0d4cf2621d7e032439341bc3f647bff125818d
# Best match: Pygments 2.3.1
# Processing Pygments-2.3.1-py2.py3-none-any.whl
# Installing Pygments-2.3.1-py2.py3-none-any.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# Adding Pygments 2.3.1 to easy-install.pth file
# Installing pygmentize script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/Pygments-2.3.1-py3.7.egg
# Searching for jupyter-core
# Reading https://pypi.org/simple/jupyter-core/
# Downloading https://files.pythonhosted.org/packages/1d/44/065d2d7bae7bebc06f1dd70d23c36da8c50c0f08b4236716743d706762a8/jupyter_core-4.4.0-py2.py3-none-any.whl#sha256=927d713ffa616ea11972534411544589976b2493fc7e09ad946e010aa7eb9970
# Best match: jupyter-core 4.4.0
# Processing jupyter_core-4.4.0-py2.py3-none-any.whl
# Installing jupyter_core-4.4.0-py2.py3-none-any.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# writing requirements to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/jupyter_core-4.4.0-py3.7.egg/EGG-INFO/requires.txt
# Adding jupyter-core 4.4.0 to easy-install.pth file
# Installing jupyter script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
# Installing jupyter-migrate script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
# Installing jupyter-troubleshoot script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/jupyter_core-4.4.0-py3.7.egg
# Searching for jupyter-client>=4.1
# Reading https://pypi.org/simple/jupyter-client/
# Downloading https://files.pythonhosted.org/packages/3b/c3/3043fe9ffd140d03c9d091a056794ccdc427c56ec19b8eea74f9ea0a498f/jupyter_client-5.2.4-py2.py3-none-any.whl#sha256=c44411eb1463ed77548bc2d5ec0d744c9b81c4a542d9637c7a52824e2121b987
# Best match: jupyter-client 5.2.4
# Processing jupyter_client-5.2.4-py2.py3-none-any.whl
# Installing jupyter_client-5.2.4-py2.py3-none-any.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# writing requirements to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/jupyter_client-5.2.4-py3.7.egg/EGG-INFO/requires.txt
# Adding jupyter-client 5.2.4 to easy-install.pth file
# Installing jupyter-kernel script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
# Installing jupyter-kernelspec script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
# Installing jupyter-run script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/jupyter_client-5.2.4-py3.7.egg
# Searching for ipython-genutils
# Reading https://pypi.org/simple/ipython-genutils/
# Downloading https://files.pythonhosted.org/packages/fa/bc/9bd3b5c2b4774d5f33b2d544f1460be9df7df2fe42f352135381c347c69a/ipython_genutils-0.2.0-py2.py3-none-any.whl#sha256=72dd37233799e619666c9f639a9da83c34013a73e8bbc79a7a6348d93c61fab8
# Best match: ipython-genutils 0.2.0
# Processing ipython_genutils-0.2.0-py2.py3-none-any.whl
# Installing ipython_genutils-0.2.0-py2.py3-none-any.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# Adding ipython-genutils 0.2.0 to easy-install.pth file
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/ipython_genutils-0.2.0-py3.7.egg
# Searching for tornado<7,>=4.1
# Reading https://pypi.org/simple/tornado/
# Downloading https://files.pythonhosted.org/packages/b1/7f/8109821ff9df1bf3519169e34646705c32ac13be6a4d51a79ed57f47686e/tornado-6.0.1.tar.gz#sha256=de274c65f45f6656c375cdf1759dbf0bc52902a1e999d12a35eb13020a641a53
# Best match: tornado 6.0.1
# Processing tornado-6.0.1.tar.gz
# Writing /var/folders/9k/n5kcz5zn0yn6y3xcbv2kfxhr0000gn/T/easy_install-vdlzevsb/tornado-6.0.1/setup.cfg
# Running tornado-6.0.1/setup.py -q bdist_egg --dist-dir /var/folders/9k/n5kcz5zn0yn6y3xcbv2kfxhr0000gn/T/easy_install-vdlzevsb/tornado-6.0.1/egg-dist-tmp-194891n0
# creating /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/tornado-6.0.1-py3.7-macosx-10.14-x86_64.egg
# Extracting tornado-6.0.1-py3.7-macosx-10.14-x86_64.egg to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# Adding tornado 6.0.1 to easy-install.pth file
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/tornado-6.0.1-py3.7-macosx-10.14-x86_64.egg
# Searching for terminado>=0.8.1
# Reading https://pypi.org/simple/terminado/
# Downloading https://files.pythonhosted.org/packages/2e/20/a26211a24425923d46e1213b376a6ee60dc30bcdf1b0c345e2c3769deb1c/terminado-0.8.1-py2.py3-none-any.whl#sha256=65011551baff97f5414c67018e908110693143cfbaeb16831b743fe7cad8b927
# Best match: terminado 0.8.1
# Processing terminado-0.8.1-py2.py3-none-any.whl
# Installing terminado-0.8.1-py2.py3-none-any.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# writing requirements to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/terminado-0.8.1-py3.7.egg/EGG-INFO/requires.txt
# Adding terminado 0.8.1 to easy-install.pth file
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/terminado-0.8.1-py3.7.egg
# Searching for pyzmq>=17
# Reading https://pypi.org/simple/pyzmq/
# Downloading https://files.pythonhosted.org/packages/30/08/64b910e8f5e0285598a15a8d8f2f4d06a1367f0d145c7554fdd02d926272/pyzmq-18.0.1-cp37-cp37m-macosx_10_9_x86_64.whl#sha256=5ccb9b3d4cd20c000a9b75689d5add8cd3bce67fcbd0f8ae1b59345247d803af
# Best match: pyzmq 18.0.1
# Processing pyzmq-18.0.1-cp37-cp37m-macosx_10_9_x86_64.whl
# Installing pyzmq-18.0.1-cp37-cp37m-macosx_10_9_x86_64.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# Adding pyzmq 18.0.1 to easy-install.pth file
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/pyzmq-18.0.1-py3.7-macosx-10.14-x86_64.egg
# Searching for prometheus-client
# Reading https://pypi.org/simple/prometheus-client/
# Downloading https://files.pythonhosted.org/packages/4c/bd/b42db3ec90ffc6be805aad09c1cea4bb13a620d0cd4b21aaa44d13541d71/prometheus_client-0.6.0.tar.gz#sha256=1b38b958750f66f208bcd9ab92a633c0c994d8859c831f7abc1f46724fcee490
# Best match: prometheus-client 0.6.0
# Processing prometheus_client-0.6.0.tar.gz
# Writing /var/folders/9k/n5kcz5zn0yn6y3xcbv2kfxhr0000gn/T/easy_install-ezb0vzs9/prometheus_client-0.6.0/setup.cfg
# Running prometheus_client-0.6.0/setup.py -q bdist_egg --dist-dir /var/folders/9k/n5kcz5zn0yn6y3xcbv2kfxhr0000gn/T/easy_install-ezb0vzs9/prometheus_client-0.6.0/egg-dist-tmp-xhwzcvao
# Copying prometheus_client-0.6.0-py3.7.egg to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# Adding prometheus-client 0.6.0 to easy-install.pth file
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/prometheus_client-0.6.0-py3.7.egg
# Searching for nbformat
# Reading https://pypi.org/simple/nbformat/
# Downloading https://files.pythonhosted.org/packages/da/27/9a654d2b6cc1eaa517d1c5a4405166c7f6d72f04f6e7eea41855fe808a46/nbformat-4.4.0-py2.py3-none-any.whl#sha256=b9a0dbdbd45bb034f4f8893cafd6f652ea08c8c1674ba83f2dc55d3955743b0b
# Best match: nbformat 4.4.0
# Processing nbformat-4.4.0-py2.py3-none-any.whl
# Installing nbformat-4.4.0-py2.py3-none-any.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# writing requirements to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/nbformat-4.4.0-py3.7.egg/EGG-INFO/requires.txt
# Adding nbformat 4.4.0 to easy-install.pth file
# Installing jupyter-trust script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/nbformat-4.4.0-py3.7.egg
# Searching for Send2Trash
# Reading https://pypi.org/simple/Send2Trash/
# Downloading https://files.pythonhosted.org/packages/49/46/c3dc27481d1cc57b9385aff41c474ceb7714f7935b1247194adae45db714/Send2Trash-1.5.0-py3-none-any.whl#sha256=f1691922577b6fa12821234aeb57599d887c4900b9ca537948d2dac34aea888b
# Best match: Send2Trash 1.5.0
# Processing Send2Trash-1.5.0-py3-none-any.whl
# Installing Send2Trash-1.5.0-py3-none-any.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# Adding Send2Trash 1.5.0 to easy-install.pth file
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/Send2Trash-1.5.0-py3.7.egg
# Searching for testpath
# Reading https://pypi.org/simple/testpath/
# Downloading https://files.pythonhosted.org/packages/be/a4/162f9ebb6489421fe46dcca2ae420369edfee4b563c668d93cb4605d12ba/testpath-0.4.2-py2.py3-none-any.whl#sha256=46c89ebb683f473ffe2aab0ed9f12581d4d078308a3cb3765d79c6b2317b0109
# Best match: testpath 0.4.2
# Processing testpath-0.4.2-py2.py3-none-any.whl
# Installing testpath-0.4.2-py2.py3-none-any.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# writing requirements to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/testpath-0.4.2-py3.7.egg/EGG-INFO/requires.txt
# Adding testpath 0.4.2 to easy-install.pth file
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/testpath-0.4.2-py3.7.egg
# Searching for pandocfilters>=1.4.1
# Reading https://pypi.org/simple/pandocfilters/
# Downloading https://files.pythonhosted.org/packages/4c/ea/236e2584af67bb6df960832731a6e5325fd4441de001767da328c33368ce/pandocfilters-1.4.2.tar.gz#sha256=b3dd70e169bb5449e6bc6ff96aea89c5eea8c5f6ab5e207fc2f521a2cf4a0da9
# Best match: pandocfilters 1.4.2
# Processing pandocfilters-1.4.2.tar.gz
# Writing /var/folders/9k/n5kcz5zn0yn6y3xcbv2kfxhr0000gn/T/easy_install-aczww8c2/pandocfilters-1.4.2/setup.cfg
# Running pandocfilters-1.4.2/setup.py -q bdist_egg --dist-dir /var/folders/9k/n5kcz5zn0yn6y3xcbv2kfxhr0000gn/T/easy_install-aczww8c2/pandocfilters-1.4.2/egg-dist-tmp-urnzdakf
# Copying pandocfilters-1.4.2-py3.7.egg to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# Adding pandocfilters 1.4.2 to easy-install.pth file
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/pandocfilters-1.4.2-py3.7.egg
# Searching for mistune>=0.8.1
# Reading https://pypi.org/simple/mistune/
# Downloading https://files.pythonhosted.org/packages/09/ec/4b43dae793655b7d8a25f76119624350b4d65eb663459eb9603d7f1f0345/mistune-0.8.4-py2.py3-none-any.whl#sha256=88a1051873018da288eee8538d476dffe1262495144b33ecb586c4ab266bb8d4
# Best match: mistune 0.8.4
# Processing mistune-0.8.4-py2.py3-none-any.whl
# Installing mistune-0.8.4-py2.py3-none-any.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# Adding mistune 0.8.4 to easy-install.pth file
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/mistune-0.8.4-py3.7.egg
# Searching for entrypoints>=0.2.2
# Reading https://pypi.org/simple/entrypoints/
# Downloading https://files.pythonhosted.org/packages/ac/c6/44694103f8c221443ee6b0041f69e2740d89a25641e62fb4f2ee568f2f9c/entrypoints-0.3-py2.py3-none-any.whl#sha256=589f874b313739ad35be6e0cd7efde2a4e9b6fea91edcc34e58ecbb8dbe56d19
# Best match: entrypoints 0.3
# Processing entrypoints-0.3-py2.py3-none-any.whl
# Installing entrypoints-0.3-py2.py3-none-any.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# writing requirements to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/entrypoints-0.3-py3.7.egg/EGG-INFO/requires.txt
# Adding entrypoints 0.3 to easy-install.pth file
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/entrypoints-0.3-py3.7.egg
# Searching for defusedxml
# Reading https://pypi.org/simple/defusedxml/
# Downloading https://files.pythonhosted.org/packages/87/1c/17f3e3935a913dfe2a5ca85fa5ccbef366bfd82eb318b1f75dadbf0affca/defusedxml-0.5.0-py2.py3-none-any.whl#sha256=702a91ade2968a82beb0db1e0766a6a273f33d4616a6ce8cde475d8e09853b20
# Best match: defusedxml 0.5.0
# Processing defusedxml-0.5.0-py2.py3-none-any.whl
# Installing defusedxml-0.5.0-py2.py3-none-any.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# Adding defusedxml 0.5.0 to easy-install.pth file
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/defusedxml-0.5.0-py3.7.egg
# Searching for bleach
# Reading https://pypi.org/simple/bleach/
# Downloading https://files.pythonhosted.org/packages/ab/05/27e1466475e816d3001efb6e0a85a819be17411420494a1e602c36f8299d/bleach-3.1.0-py2.py3-none-any.whl#sha256=213336e49e102af26d9cde77dd2d0397afabc5a6bf2fed985dc35b5d1e285a16
# Best match: bleach 3.1.0
# Processing bleach-3.1.0-py2.py3-none-any.whl
# Installing bleach-3.1.0-py2.py3-none-any.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# writing requirements to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/bleach-3.1.0-py3.7.egg/EGG-INFO/requires.txt
# Adding bleach 3.1.0 to easy-install.pth file
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/bleach-3.1.0-py3.7.egg
# Searching for prompt-toolkit<2.1.0,>=2.0.0
# Reading https://pypi.org/simple/prompt-toolkit/
# Downloading https://files.pythonhosted.org/packages/f7/a7/9b1dd14ef45345f186ef69d175bdd2491c40ab1dfa4b2b3e4352df719ed7/prompt_toolkit-2.0.9-py3-none-any.whl#sha256=11adf3389a996a6d45cc277580d0d53e8a5afd281d0c9ec71b28e6f121463780
# Best match: prompt-toolkit 2.0.9
# Processing prompt_toolkit-2.0.9-py3-none-any.whl
# Installing prompt_toolkit-2.0.9-py3-none-any.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# writing requirements to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/prompt_toolkit-2.0.9-py3.7.egg/EGG-INFO/requires.txt
# Adding prompt-toolkit 2.0.9 to easy-install.pth file
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/prompt_toolkit-2.0.9-py3.7.egg
# Searching for ipython
# Reading https://pypi.org/simple/ipython/
# Downloading https://files.pythonhosted.org/packages/14/3b/3fcf422a99a04ee493e6a4fc3014e3c8ff484a7feed238fef68bdc285085/ipython-7.3.0-py3-none-any.whl#sha256=5d3e020a6b5f29df037555e5c45ab1088d6a7cf3bd84f47e0ba501eeb0c3ec82
# Best match: ipython 7.3.0
# Processing ipython-7.3.0-py3-none-any.whl
# Installing ipython-7.3.0-py3-none-any.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# writing requirements to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/ipython-7.3.0-py3.7.egg/EGG-INFO/requires.txt
# Adding ipython 7.3.0 to easy-install.pth file
# Installing iptest script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
# Installing iptest3 script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
# Installing ipython script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
# Installing ipython3 script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/ipython-7.3.0-py3.7.egg
# Searching for widgetsnbextension~=3.4.0
# Reading https://pypi.org/simple/widgetsnbextension/
# Downloading https://files.pythonhosted.org/packages/8a/81/35789a3952afb48238289171728072d26d6e76649ddc8b3588657a2d78c1/widgetsnbextension-3.4.2-py2.py3-none-any.whl#sha256=14b2c65f9940c9a7d3b70adbe713dbd38b5ec69724eebaba034d1036cf3d4740
# Best match: widgetsnbextension 3.4.2
# Processing widgetsnbextension-3.4.2-py2.py3-none-any.whl
# Installing widgetsnbextension-3.4.2-py2.py3-none-any.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# writing requirements to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/widgetsnbextension-3.4.2-py3.7.egg/EGG-INFO/requires.txt
# Adding widgetsnbextension 3.4.2 to easy-install.pth file
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/widgetsnbextension-3.4.2-py3.7.egg
# Searching for six
# Reading https://pypi.org/simple/six/
# Downloading https://files.pythonhosted.org/packages/73/fb/00a976f728d0d1fecfe898238ce23f502a721c0ac0ecfedb80e0d88c64e9/six-1.12.0-py2.py3-none-any.whl#sha256=3350809f0555b11f552448330d0b52d5f24c91a322ea4a15ef22629740f3761c
# Best match: six 1.12.0
# Processing six-1.12.0-py2.py3-none-any.whl
# Installing six-1.12.0-py2.py3-none-any.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# Adding six 1.12.0 to easy-install.pth file
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/six-1.12.0-py3.7.egg
# Searching for decorator
# Reading https://pypi.org/simple/decorator/
# Downloading https://files.pythonhosted.org/packages/5f/88/0075e461560a1e750a0dcbf77f1d9de775028c37a19a346a6c565a257399/decorator-4.4.0-py2.py3-none-any.whl#sha256=f069f3a01830ca754ba5258fde2278454a0b5b79e0d7f5c13b3b97e57d4acff6
# Best match: decorator 4.4.0
# Processing decorator-4.4.0-py2.py3-none-any.whl
# Installing decorator-4.4.0-py2.py3-none-any.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# Adding decorator 4.4.0 to easy-install.pth file
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/decorator-4.4.0-py3.7.egg
# Searching for python-dateutil>=2.1
# Reading https://pypi.org/simple/python-dateutil/
# Downloading https://files.pythonhosted.org/packages/41/17/c62faccbfbd163c7f57f3844689e3a78bae1f403648a6afb1d0866d87fbb/python_dateutil-2.8.0-py2.py3-none-any.whl#sha256=7e6584c74aeed623791615e26efd690f29817a27c73085b78e4bad02493df2fb
# Best match: python-dateutil 2.8.0
# Processing python_dateutil-2.8.0-py2.py3-none-any.whl
# Installing python_dateutil-2.8.0-py2.py3-none-any.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# writing requirements to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/python_dateutil-2.8.0-py3.7.egg/EGG-INFO/requires.txt
# Adding python-dateutil 2.8.0 to easy-install.pth file
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/python_dateutil-2.8.0-py3.7.egg
# Searching for ptyprocess
# Reading https://pypi.org/simple/ptyprocess/
# Downloading https://files.pythonhosted.org/packages/d1/29/605c2cc68a9992d18dada28206eeada56ea4bd07a239669da41674648b6f/ptyprocess-0.6.0-py2.py3-none-any.whl#sha256=d7cc528d76e76342423ca640335bd3633420dc1366f258cb31d05e865ef5ca1f
# Best match: ptyprocess 0.6.0
# Processing ptyprocess-0.6.0-py2.py3-none-any.whl
# Installing ptyprocess-0.6.0-py2.py3-none-any.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# Adding ptyprocess 0.6.0 to easy-install.pth file
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/ptyprocess-0.6.0-py3.7.egg
# Searching for jsonschema!=2.5.0,>=2.4
# Reading https://pypi.org/simple/jsonschema/
# Downloading https://files.pythonhosted.org/packages/aa/69/df679dfbdd051568b53c38ec8152a3ab6bc533434fc7ed11ab034bf5e82f/jsonschema-3.0.1-py2.py3-none-any.whl#sha256=a5f6559964a3851f59040d3b961de5e68e70971afb88ba519d27e6a039efff1a
# Best match: jsonschema 3.0.1
# Processing jsonschema-3.0.1-py2.py3-none-any.whl
# Installing jsonschema-3.0.1-py2.py3-none-any.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# writing requirements to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/jsonschema-3.0.1-py3.7.egg/EGG-INFO/requires.txt
# Adding jsonschema 3.0.1 to easy-install.pth file
# Installing jsonschema script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/jsonschema-3.0.1-py3.7.egg
# Searching for webencodings
# Reading https://pypi.org/simple/webencodings/
# Downloading https://files.pythonhosted.org/packages/f4/24/2a3e3df732393fed8b3ebf2ec078f05546de641fe1b667ee316ec1dcf3b7/webencodings-0.5.1-py2.py3-none-any.whl#sha256=a0af1213f3c2226497a97e2b3aa01a7e4bee4f403f95be16fc9acd2947514a78
# Best match: webencodings 0.5.1
# Processing webencodings-0.5.1-py2.py3-none-any.whl
# Installing webencodings-0.5.1-py2.py3-none-any.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# Adding webencodings 0.5.1 to easy-install.pth file
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/webencodings-0.5.1-py3.7.egg
# Searching for wcwidth
# Reading https://pypi.org/simple/wcwidth/
# Downloading https://files.pythonhosted.org/packages/7e/9f/526a6947247599b084ee5232e4f9190a38f398d7300d866af3ab571a5bfe/wcwidth-0.1.7-py2.py3-none-any.whl#sha256=f4ebe71925af7b40a864553f761ed559b43544f8f71746c2d756c7fe788ade7c
# Best match: wcwidth 0.1.7
# Processing wcwidth-0.1.7-py2.py3-none-any.whl
# Installing wcwidth-0.1.7-py2.py3-none-any.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# Adding wcwidth 0.1.7 to easy-install.pth file
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/wcwidth-0.1.7-py3.7.egg
# Searching for pickleshare
# Reading https://pypi.org/simple/pickleshare/
# Downloading https://files.pythonhosted.org/packages/9a/41/220f49aaea88bc6fa6cba8d05ecf24676326156c23b991e80b3f2fc24c77/pickleshare-0.7.5-py2.py3-none-any.whl#sha256=9649af414d74d4df115d5d718f82acb59c9d418196b7b4290ed47a12ce62df56
# Best match: pickleshare 0.7.5
# Processing pickleshare-0.7.5-py2.py3-none-any.whl
# Installing pickleshare-0.7.5-py2.py3-none-any.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# Adding pickleshare 0.7.5 to easy-install.pth file
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/pickleshare-0.7.5-py3.7.egg
# Searching for pexpect
# Reading https://pypi.org/simple/pexpect/
# Downloading https://files.pythonhosted.org/packages/89/e6/b5a1de8b0cc4e07ca1b305a4fcc3f9806025c1b651ea302646341222f88b/pexpect-4.6.0-py2.py3-none-any.whl#sha256=3fbd41d4caf27fa4a377bfd16fef87271099463e6fa73e92a52f92dfee5d425b
# Best match: pexpect 4.6.0
# Processing pexpect-4.6.0-py2.py3-none-any.whl
# Installing pexpect-4.6.0-py2.py3-none-any.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# writing requirements to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/pexpect-4.6.0-py3.7.egg/EGG-INFO/requires.txt
# Adding pexpect 4.6.0 to easy-install.pth file
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/pexpect-4.6.0-py3.7.egg
# Searching for jedi>=0.10
# Reading https://pypi.org/simple/jedi/
# Downloading https://files.pythonhosted.org/packages/25/2b/1f188901be099d52d7b06f4d3b7cb9f8f09692c50697b139eaf6fa2928d8/jedi-0.13.3-py2.py3-none-any.whl#sha256=2c6bcd9545c7d6440951b12b44d373479bf18123a401a52025cf98563fbd826c
# Best match: jedi 0.13.3
# Processing jedi-0.13.3-py2.py3-none-any.whl
# Installing jedi-0.13.3-py2.py3-none-any.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# writing requirements to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/jedi-0.13.3-py3.7.egg/EGG-INFO/requires.txt
# Adding jedi 0.13.3 to easy-install.pth file
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/jedi-0.13.3-py3.7.egg
# Searching for backcall
# Reading https://pypi.org/simple/backcall/
# Downloading https://files.pythonhosted.org/packages/84/71/c8ca4f5bb1e08401b916c68003acf0a0655df935d74d93bf3f3364b310e0/backcall-0.1.0.tar.gz#sha256=38ecd85be2c1e78f77fd91700c76e14667dc21e2713b63876c0eb901196e01e4
# Best match: backcall 0.1.0
# Processing backcall-0.1.0.tar.gz
# Writing /var/folders/9k/n5kcz5zn0yn6y3xcbv2kfxhr0000gn/T/easy_install-vt0komgd/backcall-0.1.0/setup.cfg
# Running backcall-0.1.0/setup.py -q bdist_egg --dist-dir /var/folders/9k/n5kcz5zn0yn6y3xcbv2kfxhr0000gn/T/easy_install-vt0komgd/backcall-0.1.0/egg-dist-tmp-97bioqgv
# Copying backcall-0.1.0-py3.7.egg to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# Adding backcall 0.1.0 to easy-install.pth file
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/backcall-0.1.0-py3.7.egg
# Searching for appnope
# Reading https://pypi.org/simple/appnope/
# Downloading https://files.pythonhosted.org/packages/87/a9/7985e6a53402f294c8f0e8eff3151a83f1fb901fa92909bb3ff29b4d22af/appnope-0.1.0-py2.py3-none-any.whl#sha256=5b26757dc6f79a3b7dc9fab95359328d5747fcb2409d331ea66d0272b90ab2a0
# Best match: appnope 0.1.0
# Processing appnope-0.1.0-py2.py3-none-any.whl
# Installing appnope-0.1.0-py2.py3-none-any.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# Adding appnope 0.1.0 to easy-install.pth file
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/appnope-0.1.0-py3.7.egg
# Searching for pyrsistent>=0.14.0
# Reading https://pypi.org/simple/pyrsistent/
# Downloading https://files.pythonhosted.org/packages/8c/46/4e93ab8a379d7efe93f20a0fb8a27bdfe88942cc954ab0210c3164e783e0/pyrsistent-0.14.11.tar.gz#sha256=3ca82748918eb65e2d89f222b702277099aca77e34843c5eb9d52451173970e2
# Best match: pyrsistent 0.14.11
# Processing pyrsistent-0.14.11.tar.gz
# Writing /var/folders/9k/n5kcz5zn0yn6y3xcbv2kfxhr0000gn/T/easy_install-0vyoql7i/pyrsistent-0.14.11/setup.cfg
# Running pyrsistent-0.14.11/setup.py -q bdist_egg --dist-dir /var/folders/9k/n5kcz5zn0yn6y3xcbv2kfxhr0000gn/T/easy_install-0vyoql7i/pyrsistent-0.14.11/egg-dist-tmp-g_qbpnos
# creating /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/pyrsistent-0.14.11-py3.7-macosx-10.14-x86_64.egg
# Extracting pyrsistent-0.14.11-py3.7-macosx-10.14-x86_64.egg to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# Adding pyrsistent 0.14.11 to easy-install.pth file
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/pyrsistent-0.14.11-py3.7-macosx-10.14-x86_64.egg
# Searching for attrs>=17.4.0
# Reading https://pypi.org/simple/attrs/
# Downloading https://files.pythonhosted.org/packages/23/96/d828354fa2dbdf216eaa7b7de0db692f12c234f7ef888cc14980ef40d1d2/attrs-19.1.0-py2.py3-none-any.whl#sha256=69c0dbf2ed392de1cb5ec704444b08a5ef81680a61cb899dc08127123af36a79
# Best match: attrs 19.1.0
# Processing attrs-19.1.0-py2.py3-none-any.whl
# Installing attrs-19.1.0-py2.py3-none-any.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# writing requirements to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/attrs-19.1.0-py3.7.egg/EGG-INFO/requires.txt
# Adding attrs 19.1.0 to easy-install.pth file
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/attrs-19.1.0-py3.7.egg
# Searching for parso>=0.3.0
# Reading https://pypi.org/simple/parso/
# Downloading https://files.pythonhosted.org/packages/19/b1/522b2671cc6d134c9d3f5dfc0d02fee07cab848e908d03d2bffea78cca8f/parso-0.3.4-py2.py3-none-any.whl#sha256=4580328ae3f548b358f4901e38c0578229186835f0fa0846e47369796dd5bcc9
# Best match: parso 0.3.4
# Processing parso-0.3.4-py2.py3-none-any.whl
# Installing parso-0.3.4-py2.py3-none-any.whl to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# writing requirements to /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/parso-0.3.4-py3.7.egg/EGG-INFO/requires.txt
# Adding parso 0.3.4 to easy-install.pth file
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/parso-0.3.4-py3.7.egg
# Searching for setuptools==40.6.2
# Best match: setuptools 40.6.2
# Adding setuptools 40.6.2 to easy-install.pth file
# Installing easy_install script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
# Installing easy_install-3.6 script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# Finished processing dependencies for MyProject==0.1
# warning: no files found matching '*.yaml' under directory 'demos'
# no previously-included directories found matching 'docs/build'
# warning: no files found matching 'tornado/test/README'
# zip_safe flag not set; analyzing archive contents...
# tornado.__pycache__.autoreload.cpython-37: module references __file__
# tornado.__pycache__.gen.cpython-37: module references __file__
# tornado.__pycache__.options.cpython-37: module references __file__
# tornado.__pycache__.speedups.cpython-37: module references __file__
# tornado.__pycache__.testing.cpython-37: module references __file__
# tornado.test.__pycache__.gen_test.cpython-37: module references __file__
# tornado.test.__pycache__.httpserver_test.cpython-37: module references __file__
# tornado.test.__pycache__.iostream_test.cpython-37: module references __file__
# tornado.test.__pycache__.locale_test.cpython-37: module references __file__
# tornado.test.__pycache__.options_test.cpython-37: module references __file__
# tornado.test.__pycache__.template_test.cpython-37: module references __file__
# tornado.test.__pycache__.web_test.cpython-37: module references __file__
# zip_safe flag not set; analyzing archive contents...
# zip_safe flag not set; analyzing archive contents...
# zip_safe flag not set; analyzing archive contents...
# pvectorcmodule.c:152:21: warning: comparison of integers of different signs: 'int' and 'unsigned int' [-Wsign-compare]
#   if((i >= 0) && (i < self->count)) {
#                   ~ ^ ~~~~~~~~~~~
# pvectorcmodule.c:153:10: warning: comparison of integers of different signs: 'int' and 'unsigned int' [-Wsign-compare]
#     if(i >= TAIL_OFF(self)) {
#        ~ ^  ~~~~~~~~~~~~~~
# pvectorcmodule.c:428:17: warning: comparison of integers of different signs: 'int' and 'unsigned int' [-Wsign-compare]
#       for(j=0; j<self->count; j++) {
#                ~^~~~~~~~~~~~
# 3 warnings generated.
# zip_safe flag not set; analyzing archive contents...
# __pycache__.pvectorc.cpython-37: module references __file__

# %%
cat data/MyProject/env/lib/python3.7/site-packages/easy-install.pth
# Out:
# /Users/rick446/src/arborian-classes/data/MyProject
# ./numpy-1.16.2-py3.7-macosx-10.14-x86_64.egg
# ./Flask-1.0.2-py3.7.egg
# ./jupyter-1.0.0-py3.7.egg
# ./itsdangerous-1.1.0-py3.7.egg
# ./Click-7.0-py3.7.egg
# ./Werkzeug-0.15.1-py3.7.egg
# ./Jinja2-2.10-py3.7.egg
# ./qtconsole-4.4.3-py3.7.egg
# ./notebook-5.7.6-py3.7.egg
# ./nbconvert-5.4.1-py3.7.egg
# ./jupyter_console-6.0.0-py3.7.egg
# ./ipywidgets-7.4.2-py3.7.egg
# ./ipykernel-5.1.0-py3.7.egg
# ./MarkupSafe-1.1.1-py3.7-macosx-10.14-x86_64.egg
# ./traitlets-4.3.2-py3.7.egg
# ./Pygments-2.3.1-py3.7.egg
# ./jupyter_core-4.4.0-py3.7.egg
# ./jupyter_client-5.2.4-py3.7.egg
# ./ipython_genutils-0.2.0-py3.7.egg
# ./tornado-6.0.1-py3.7-macosx-10.14-x86_64.egg
# ./terminado-0.8.1-py3.7.egg
# ./pyzmq-18.0.1-py3.7-macosx-10.14-x86_64.egg
# ./prometheus_client-0.6.0-py3.7.egg
# ./nbformat-4.4.0-py3.7.egg
# ./Send2Trash-1.5.0-py3.7.egg
# ./testpath-0.4.2-py3.7.egg
# ./pandocfilters-1.4.2-py3.7.egg
# ./mistune-0.8.4-py3.7.egg
# ./entrypoints-0.3-py3.7.egg
# ./defusedxml-0.5.0-py3.7.egg
# ./bleach-3.1.0-py3.7.egg
# ./prompt_toolkit-2.0.9-py3.7.egg
# ./ipython-7.3.0-py3.7.egg
# ./widgetsnbextension-3.4.2-py3.7.egg
# ./six-1.12.0-py3.7.egg
# ./decorator-4.4.0-py3.7.egg
# ./python_dateutil-2.8.0-py3.7.egg
# ./ptyprocess-0.6.0-py3.7.egg
# ./jsonschema-3.0.1-py3.7.egg
# ./webencodings-0.5.1-py3.7.egg
# ./wcwidth-0.1.7-py3.7.egg
# ./pickleshare-0.7.5-py3.7.egg
# ./pexpect-4.6.0-py3.7.egg
# ./jedi-0.13.3-py3.7.egg
# ./backcall-0.1.0-py3.7.egg
# ./appnope-0.1.0-py3.7.egg
# ./pyrsistent-0.14.11-py3.7-macosx-10.14-x86_64.egg
# ./attrs-19.1.0-py3.7.egg
# ./parso-0.3.4-py3.7.egg

# %%
# %%bash
# source data/MyProject/env/bin/activate
# python -c 'import mypackage.mymodule; mypackage.mymodule.greet("class")'
# Out:
# This is the __init__ file for mypackage
# This is mymodule
# Hello, class!

# %% [markdown]
# ## Distributing data with our project
#
# Normally, only Python files are included with our project. In order to include non-Python files, we need to specify those as well:

# %%
# %%file data/MyProject/mypackage/template.txt
# This is an awesome template that greets you.
#
# Hello, ${name}!
# Out:
# Writing data/MyProject/mypackage/template.txt

# %%
# %%file data/MyProject/mypackage/mymodule.py
import os, string


def greet(name):
    with open(os.path.join(
        os.path.dirname(__file__),
        'template.txt'
    )) as f:
        template = string.Template(f.read())
    print(template.safe_substitute({'name': name}))
# Out:
# Overwriting data/MyProject/mypackage/mymodule.py

# %%
# %%file data/MyProject/setup.cfg
# [metadata]
# name = MyProject
# url = file:///
# author = Some Person
# author_email = somebody@example.com
# version = 0.1
# description = This should be a short description of our project
# long_description = file: README.md
# classifiers =
#     Programming Language :: Python :: 3
#     Programming Language :: Python :: 3.7
# keywords = test, class
#
# [options]
# packages = mypackage
# install_requires =
#     jupyter
#     flask
#     numpy>=1.16.0<1.17
#
# [options.package_data]
# * = *.txt
# Out:
# Overwriting data/MyProject/setup.cfg

# %%
# %%bash
# cd data/MyProject
# python setup.py sdist
# Out:
# running sdist
# running egg_info
# writing MyProject.egg-info/PKG-INFO
# writing dependency_links to MyProject.egg-info/dependency_links.txt
# writing requirements to MyProject.egg-info/requires.txt
# writing top-level names to MyProject.egg-info/top_level.txt
# reading manifest file 'MyProject.egg-info/SOURCES.txt'
# writing manifest file 'MyProject.egg-info/SOURCES.txt'
# running check
# creating MyProject-0.1
# creating MyProject-0.1/MyProject.egg-info
# creating MyProject-0.1/mypackage
# copying files to MyProject-0.1...
# copying README.md -> MyProject-0.1
# copying setup.cfg -> MyProject-0.1
# copying setup.py -> MyProject-0.1
# copying MyProject.egg-info/PKG-INFO -> MyProject-0.1/MyProject.egg-info
# copying MyProject.egg-info/SOURCES.txt -> MyProject-0.1/MyProject.egg-info
# copying MyProject.egg-info/dependency_links.txt -> MyProject-0.1/MyProject.egg-info
# copying MyProject.egg-info/requires.txt -> MyProject-0.1/MyProject.egg-info
# copying MyProject.egg-info/top_level.txt -> MyProject-0.1/MyProject.egg-info
# copying mypackage/__init__.py -> MyProject-0.1/mypackage
# copying mypackage/mymodule.py -> MyProject-0.1/mypackage
# copying mypackage/template.txt -> MyProject-0.1/mypackage
# Writing MyProject-0.1/setup.cfg
# Creating tar archive
# removing 'MyProject-0.1' (and everything under it)

# %%
# %%bash
# source data/MyProject/env/bin/activate
# python -c 'import mypackage.mymodule; mypackage.mymodule.greet("class")'
# Out:
# This is the __init__ file for mypackage
# This is an awesome template that greets you.
#
# Hello, class!

# %% [markdown]
# # Using entry_points for console_scripts
#
# If you need to create a new command-line tool, a nice approach is to use the `entry_points` feature of `setuptools`:

# %%
# %%file data/MyProject/setup.cfg
# [metadata]
# name = MyProject
# url = file:///
# author = Some Person
# author_email = somebody@example.com
# version = 0.1
# description = This should be a short description of our project
# long_description = file: README.md
# classifiers =
#     Programming Language :: Python :: 3
#     Programming Language :: Python :: 3.7
# keywords = test, class
#
# [options]
# packages = mypackage
# install_requires =
#     jupyter
#     flask
#     numpy>=1.16.0<1.17
#
# [options.package_data]
# * = *.txt
#
# [options.entry_points]
# console_scripts =
#   my-greet=mypackage.mymodule:greet_main
# Out:
# Overwriting data/MyProject/setup.cfg

# %%
# %%file data/MyProject/mypackage/mymodule.py
import os, sys, string


def greet(name):
    with open(os.path.join(
        os.path.dirname(__file__),
        'template.txt'
    )) as f:
        template = string.Template(f.read())
    print(template.safe_substitute({'name': name}))
    
    
def greet_main():
    if len(sys.argv) > 1:
        name = sys.argv[1]
    else:
        name = 'unknown human'
    greet(name)
# Out:
# Overwriting data/MyProject/mypackage/mymodule.py

# %%
# %%bash
# cd data/MyProject
# python -m venv env
# source env/bin/activate
# python setup.py develop
# Out:
# running develop
# running egg_info
# writing MyProject.egg-info/PKG-INFO
# writing dependency_links to MyProject.egg-info/dependency_links.txt
# writing entry points to MyProject.egg-info/entry_points.txt
# writing requirements to MyProject.egg-info/requires.txt
# writing top-level names to MyProject.egg-info/top_level.txt
# reading manifest file 'MyProject.egg-info/SOURCES.txt'
# writing manifest file 'MyProject.egg-info/SOURCES.txt'
# running build_ext
# Creating /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/MyProject.egg-link (link to .)
# MyProject 0.1 is already the active version in easy-install.pth
# Installing my-greet script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
#
# Installed /Users/rick446/src/arborian-classes/data/MyProject
# Processing dependencies for MyProject==0.1
# Searching for numpy==1.16.2
# Best match: numpy 1.16.2
# Processing numpy-1.16.2-py3.7-macosx-10.14-x86_64.egg
# numpy 1.16.2 is already the active version in easy-install.pth
# Installing f2py script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
# Installing f2py3 script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
# Installing f2py3.7 script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/numpy-1.16.2-py3.7-macosx-10.14-x86_64.egg
# Searching for Flask==1.0.2
# Best match: Flask 1.0.2
# Processing Flask-1.0.2-py3.7.egg
# Flask 1.0.2 is already the active version in easy-install.pth
# Installing flask script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/Flask-1.0.2-py3.7.egg
# Searching for jupyter==1.0.0
# Best match: jupyter 1.0.0
# Processing jupyter-1.0.0-py3.7.egg
# jupyter 1.0.0 is already the active version in easy-install.pth
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/jupyter-1.0.0-py3.7.egg
# Searching for itsdangerous==1.1.0
# Best match: itsdangerous 1.1.0
# Processing itsdangerous-1.1.0-py3.7.egg
# itsdangerous 1.1.0 is already the active version in easy-install.pth
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/itsdangerous-1.1.0-py3.7.egg
# Searching for Click==7.0
# Best match: Click 7.0
# Processing Click-7.0-py3.7.egg
# Click 7.0 is already the active version in easy-install.pth
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/Click-7.0-py3.7.egg
# Searching for Werkzeug==0.15.1
# Best match: Werkzeug 0.15.1
# Processing Werkzeug-0.15.1-py3.7.egg
# Werkzeug 0.15.1 is already the active version in easy-install.pth
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/Werkzeug-0.15.1-py3.7.egg
# Searching for Jinja2==2.10
# Best match: Jinja2 2.10
# Processing Jinja2-2.10-py3.7.egg
# Jinja2 2.10 is already the active version in easy-install.pth
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/Jinja2-2.10-py3.7.egg
# Searching for qtconsole==4.4.3
# Best match: qtconsole 4.4.3
# Processing qtconsole-4.4.3-py3.7.egg
# qtconsole 4.4.3 is already the active version in easy-install.pth
# Installing jupyter-qtconsole script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/qtconsole-4.4.3-py3.7.egg
# Searching for notebook==5.7.6
# Best match: notebook 5.7.6
# Processing notebook-5.7.6-py3.7.egg
# notebook 5.7.6 is already the active version in easy-install.pth
# Installing jupyter-bundlerextension script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
# Installing jupyter-nbextension script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
# Installing jupyter-notebook script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
# Installing jupyter-serverextension script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/notebook-5.7.6-py3.7.egg
# Searching for nbconvert==5.4.1
# Best match: nbconvert 5.4.1
# Processing nbconvert-5.4.1-py3.7.egg
# nbconvert 5.4.1 is already the active version in easy-install.pth
# Installing jupyter-nbconvert script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/nbconvert-5.4.1-py3.7.egg
# Searching for jupyter-console==6.0.0
# Best match: jupyter-console 6.0.0
# Processing jupyter_console-6.0.0-py3.7.egg
# jupyter-console 6.0.0 is already the active version in easy-install.pth
# Installing jupyter-console script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/jupyter_console-6.0.0-py3.7.egg
# Searching for ipywidgets==7.4.2
# Best match: ipywidgets 7.4.2
# Processing ipywidgets-7.4.2-py3.7.egg
# ipywidgets 7.4.2 is already the active version in easy-install.pth
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/ipywidgets-7.4.2-py3.7.egg
# Searching for ipykernel==5.1.0
# Best match: ipykernel 5.1.0
# Processing ipykernel-5.1.0-py3.7.egg
# ipykernel 5.1.0 is already the active version in easy-install.pth
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/ipykernel-5.1.0-py3.7.egg
# Searching for MarkupSafe==1.1.1
# Best match: MarkupSafe 1.1.1
# Processing MarkupSafe-1.1.1-py3.7-macosx-10.14-x86_64.egg
# MarkupSafe 1.1.1 is already the active version in easy-install.pth
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/MarkupSafe-1.1.1-py3.7-macosx-10.14-x86_64.egg
# Searching for traitlets==4.3.2
# Best match: traitlets 4.3.2
# Processing traitlets-4.3.2-py3.7.egg
# traitlets 4.3.2 is already the active version in easy-install.pth
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/traitlets-4.3.2-py3.7.egg
# Searching for Pygments==2.3.1
# Best match: Pygments 2.3.1
# Processing Pygments-2.3.1-py3.7.egg
# Pygments 2.3.1 is already the active version in easy-install.pth
# Installing pygmentize script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/Pygments-2.3.1-py3.7.egg
# Searching for jupyter-core==4.4.0
# Best match: jupyter-core 4.4.0
# Processing jupyter_core-4.4.0-py3.7.egg
# jupyter-core 4.4.0 is already the active version in easy-install.pth
# Installing jupyter script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
# Installing jupyter-migrate script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
# Installing jupyter-troubleshoot script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/jupyter_core-4.4.0-py3.7.egg
# Searching for jupyter-client==5.2.4
# Best match: jupyter-client 5.2.4
# Processing jupyter_client-5.2.4-py3.7.egg
# jupyter-client 5.2.4 is already the active version in easy-install.pth
# Installing jupyter-kernel script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
# Installing jupyter-kernelspec script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
# Installing jupyter-run script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/jupyter_client-5.2.4-py3.7.egg
# Searching for ipython-genutils==0.2.0
# Best match: ipython-genutils 0.2.0
# Processing ipython_genutils-0.2.0-py3.7.egg
# ipython-genutils 0.2.0 is already the active version in easy-install.pth
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/ipython_genutils-0.2.0-py3.7.egg
# Searching for tornado==6.0.1
# Best match: tornado 6.0.1
# Processing tornado-6.0.1-py3.7-macosx-10.14-x86_64.egg
# tornado 6.0.1 is already the active version in easy-install.pth
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/tornado-6.0.1-py3.7-macosx-10.14-x86_64.egg
# Searching for terminado==0.8.1
# Best match: terminado 0.8.1
# Processing terminado-0.8.1-py3.7.egg
# terminado 0.8.1 is already the active version in easy-install.pth
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/terminado-0.8.1-py3.7.egg
# Searching for pyzmq==18.0.1
# Best match: pyzmq 18.0.1
# Processing pyzmq-18.0.1-py3.7-macosx-10.14-x86_64.egg
# pyzmq 18.0.1 is already the active version in easy-install.pth
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/pyzmq-18.0.1-py3.7-macosx-10.14-x86_64.egg
# Searching for prometheus-client==0.6.0
# Best match: prometheus-client 0.6.0
# Processing prometheus_client-0.6.0-py3.7.egg
# prometheus-client 0.6.0 is already the active version in easy-install.pth
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/prometheus_client-0.6.0-py3.7.egg
# Searching for nbformat==4.4.0
# Best match: nbformat 4.4.0
# Processing nbformat-4.4.0-py3.7.egg
# nbformat 4.4.0 is already the active version in easy-install.pth
# Installing jupyter-trust script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/nbformat-4.4.0-py3.7.egg
# Searching for Send2Trash==1.5.0
# Best match: Send2Trash 1.5.0
# Processing Send2Trash-1.5.0-py3.7.egg
# Send2Trash 1.5.0 is already the active version in easy-install.pth
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/Send2Trash-1.5.0-py3.7.egg
# Searching for testpath==0.4.2
# Best match: testpath 0.4.2
# Processing testpath-0.4.2-py3.7.egg
# testpath 0.4.2 is already the active version in easy-install.pth
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/testpath-0.4.2-py3.7.egg
# Searching for pandocfilters==1.4.2
# Best match: pandocfilters 1.4.2
# Processing pandocfilters-1.4.2-py3.7.egg
# pandocfilters 1.4.2 is already the active version in easy-install.pth
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/pandocfilters-1.4.2-py3.7.egg
# Searching for mistune==0.8.4
# Best match: mistune 0.8.4
# Processing mistune-0.8.4-py3.7.egg
# mistune 0.8.4 is already the active version in easy-install.pth
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/mistune-0.8.4-py3.7.egg
# Searching for entrypoints==0.3
# Best match: entrypoints 0.3
# Processing entrypoints-0.3-py3.7.egg
# entrypoints 0.3 is already the active version in easy-install.pth
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/entrypoints-0.3-py3.7.egg
# Searching for defusedxml==0.5.0
# Best match: defusedxml 0.5.0
# Processing defusedxml-0.5.0-py3.7.egg
# defusedxml 0.5.0 is already the active version in easy-install.pth
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/defusedxml-0.5.0-py3.7.egg
# Searching for bleach==3.1.0
# Best match: bleach 3.1.0
# Processing bleach-3.1.0-py3.7.egg
# bleach 3.1.0 is already the active version in easy-install.pth
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/bleach-3.1.0-py3.7.egg
# Searching for prompt-toolkit==2.0.9
# Best match: prompt-toolkit 2.0.9
# Processing prompt_toolkit-2.0.9-py3.7.egg
# prompt-toolkit 2.0.9 is already the active version in easy-install.pth
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/prompt_toolkit-2.0.9-py3.7.egg
# Searching for ipython==7.3.0
# Best match: ipython 7.3.0
# Processing ipython-7.3.0-py3.7.egg
# ipython 7.3.0 is already the active version in easy-install.pth
# Installing iptest script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
# Installing iptest3 script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
# Installing ipython script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
# Installing ipython3 script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/ipython-7.3.0-py3.7.egg
# Searching for widgetsnbextension==3.4.2
# Best match: widgetsnbextension 3.4.2
# Processing widgetsnbextension-3.4.2-py3.7.egg
# widgetsnbextension 3.4.2 is already the active version in easy-install.pth
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/widgetsnbextension-3.4.2-py3.7.egg
# Searching for six==1.12.0
# Best match: six 1.12.0
# Processing six-1.12.0-py3.7.egg
# six 1.12.0 is already the active version in easy-install.pth
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/six-1.12.0-py3.7.egg
# Searching for decorator==4.4.0
# Best match: decorator 4.4.0
# Processing decorator-4.4.0-py3.7.egg
# decorator 4.4.0 is already the active version in easy-install.pth
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/decorator-4.4.0-py3.7.egg
# Searching for python-dateutil==2.8.0
# Best match: python-dateutil 2.8.0
# Processing python_dateutil-2.8.0-py3.7.egg
# python-dateutil 2.8.0 is already the active version in easy-install.pth
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/python_dateutil-2.8.0-py3.7.egg
# Searching for ptyprocess==0.6.0
# Best match: ptyprocess 0.6.0
# Processing ptyprocess-0.6.0-py3.7.egg
# ptyprocess 0.6.0 is already the active version in easy-install.pth
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/ptyprocess-0.6.0-py3.7.egg
# Searching for jsonschema==3.0.1
# Best match: jsonschema 3.0.1
# Processing jsonschema-3.0.1-py3.7.egg
# jsonschema 3.0.1 is already the active version in easy-install.pth
# Installing jsonschema script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/jsonschema-3.0.1-py3.7.egg
# Searching for webencodings==0.5.1
# Best match: webencodings 0.5.1
# Processing webencodings-0.5.1-py3.7.egg
# webencodings 0.5.1 is already the active version in easy-install.pth
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/webencodings-0.5.1-py3.7.egg
# Searching for wcwidth==0.1.7
# Best match: wcwidth 0.1.7
# Processing wcwidth-0.1.7-py3.7.egg
# wcwidth 0.1.7 is already the active version in easy-install.pth
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/wcwidth-0.1.7-py3.7.egg
# Searching for setuptools==40.6.2
# Best match: setuptools 40.6.2
# Adding setuptools 40.6.2 to easy-install.pth file
# Installing easy_install script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
# Installing easy_install-3.6 script to /Users/rick446/src/arborian-classes/data/MyProject/env/bin
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages
# Searching for pickleshare==0.7.5
# Best match: pickleshare 0.7.5
# Processing pickleshare-0.7.5-py3.7.egg
# pickleshare 0.7.5 is already the active version in easy-install.pth
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/pickleshare-0.7.5-py3.7.egg
# Searching for pexpect==4.6.0
# Best match: pexpect 4.6.0
# Processing pexpect-4.6.0-py3.7.egg
# pexpect 4.6.0 is already the active version in easy-install.pth
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/pexpect-4.6.0-py3.7.egg
# Searching for jedi==0.13.3
# Best match: jedi 0.13.3
# Processing jedi-0.13.3-py3.7.egg
# jedi 0.13.3 is already the active version in easy-install.pth
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/jedi-0.13.3-py3.7.egg
# Searching for backcall==0.1.0
# Best match: backcall 0.1.0
# Processing backcall-0.1.0-py3.7.egg
# backcall 0.1.0 is already the active version in easy-install.pth
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/backcall-0.1.0-py3.7.egg
# Searching for appnope==0.1.0
# Best match: appnope 0.1.0
# Processing appnope-0.1.0-py3.7.egg
# appnope 0.1.0 is already the active version in easy-install.pth
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/appnope-0.1.0-py3.7.egg
# Searching for pyrsistent==0.14.11
# Best match: pyrsistent 0.14.11
# Processing pyrsistent-0.14.11-py3.7-macosx-10.14-x86_64.egg
# pyrsistent 0.14.11 is already the active version in easy-install.pth
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/pyrsistent-0.14.11-py3.7-macosx-10.14-x86_64.egg
# Searching for attrs==19.1.0
# Best match: attrs 19.1.0
# Processing attrs-19.1.0-py3.7.egg
# attrs 19.1.0 is already the active version in easy-install.pth
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/attrs-19.1.0-py3.7.egg
# Searching for parso==0.3.4
# Best match: parso 0.3.4
# Processing parso-0.3.4-py3.7.egg
# parso 0.3.4 is already the active version in easy-install.pth
#
# Using /Users/rick446/src/arborian-classes/data/MyProject/env/lib/python3.7/site-packages/parso-0.3.4-py3.7.egg
# Finished processing dependencies for MyProject==0.1

# %%
# !data/MyProject/env/bin/my-greet
# Out:
# This is the __init__ file for mypackage
# This is an awesome template that greets you.
#
# Hello, unknown human!

# %%
# !data/MyProject/env/bin/my-greet class
# Out:
# This is the __init__ file for mypackage
# This is an awesome template that greets you.
#
# Hello, class!

# %%
cat data/MyProject/env/bin/my-greet
# Out:
# #!/Users/rick446/src/arborian-classes/data/MyProject/env/bin/python
# # EASY-INSTALL-ENTRY-SCRIPT: 'MyProject','console_scripts','my-greet'
# __requires__ = 'MyProject'
# import re
# import sys
# from pkg_resources import load_entry_point
#
# if __name__ == '__main__':
#     sys.argv[0] = re.sub(r'(-script\.pyw?|\.exe)?$', '', sys.argv[0])
#     sys.exit(
#         load_entry_point('MyProject', 'console_scripts', 'my-greet')()
#     )

# %% [markdown]
# # Registering with PyPI
#
# You'll need to create an account at http://pypi.org
#
# ...and then login using

# %%
# %%file data/MyProject/setup.cfg
# [metadata]
# ;; change name to make it unique
# name = ProductionalizingProject-1
# url = https://github.com/DevelopIntelligence
# author = Some Person
# author_email = somebody@example.com
# version = 0.3
# description = This should be a short description of our project
# long_description = file: README.md
# classifiers =
#     Programming Language :: Python :: 3
#     Programming Language :: Python :: 3.7
# keywords = test, class
#
# [options]
# packages = mypackage
# install_requires =
#     jupyter
#     flask
#     numpy>=1.16.0<1.17
#
# [options.package_data]
# * = *.txt
# Out:
# Overwriting data/MyProject/setup.cfg

# %%
# %%bash
# cd data/MyProject
# rm dist/*   # clean up old distributions
# source env/bin/activate
# pip install twine
# python setup.py sdist
# twine upload dist/*
# Out:
# Requirement already satisfied: twine in ./env/lib/python3.7/site-packages (1.13.0)
# Requirement already satisfied: requests-toolbelt!=0.9.0,>=0.8.0 in ./env/lib/python3.7/site-packages (from twine) (0.9.1)
# Requirement already satisfied: readme-renderer>=21.0 in ./env/lib/python3.7/site-packages (from twine) (24.0)
# Requirement already satisfied: tqdm>=4.14 in ./env/lib/python3.7/site-packages (from twine) (4.31.1)
# Requirement already satisfied: pkginfo>=1.4.2 in ./env/lib/python3.7/site-packages (from twine) (1.5.0.1)
# Requirement already satisfied: requests!=2.15,!=2.16,>=2.5.0 in ./env/lib/python3.7/site-packages (from twine) (2.21.0)
# Requirement already satisfied: setuptools>=0.7.0 in ./env/lib/python3.7/site-packages (from twine) (40.6.2)
# Requirement already satisfied: bleach>=2.1.0 in ./env/lib/python3.7/site-packages/bleach-3.1.0-py3.7.egg (from readme-renderer>=21.0->twine) (3.1.0)
# Requirement already satisfied: six in ./env/lib/python3.7/site-packages/six-1.12.0-py3.7.egg (from readme-renderer>=21.0->twine) (1.12.0)
# Requirement already satisfied: docutils>=0.13.1 in ./env/lib/python3.7/site-packages (from readme-renderer>=21.0->twine) (0.14)
# Requirement already satisfied: Pygments in ./env/lib/python3.7/site-packages/Pygments-2.3.1-py3.7.egg (from readme-renderer>=21.0->twine) (2.3.1)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in ./env/lib/python3.7/site-packages (from requests!=2.15,!=2.16,>=2.5.0->twine) (1.24.1)
# Requirement already satisfied: idna<2.9,>=2.5 in ./env/lib/python3.7/site-packages (from requests!=2.15,!=2.16,>=2.5.0->twine) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in ./env/lib/python3.7/site-packages (from requests!=2.15,!=2.16,>=2.5.0->twine) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in ./env/lib/python3.7/site-packages (from requests!=2.15,!=2.16,>=2.5.0->twine) (2019.3.9)
# Requirement already satisfied: webencodings in ./env/lib/python3.7/site-packages/webencodings-0.5.1-py3.7.egg (from bleach>=2.1.0->readme-renderer>=21.0->twine) (0.5.1)
# running sdist
# running egg_info
# creating ProductionalizingProject_1.egg-info
# writing ProductionalizingProject_1.egg-info/PKG-INFO
# writing dependency_links to ProductionalizingProject_1.egg-info/dependency_links.txt
# writing requirements to ProductionalizingProject_1.egg-info/requires.txt
# writing top-level names to ProductionalizingProject_1.egg-info/top_level.txt
# writing manifest file 'ProductionalizingProject_1.egg-info/SOURCES.txt'
# reading manifest file 'ProductionalizingProject_1.egg-info/SOURCES.txt'
# writing manifest file 'ProductionalizingProject_1.egg-info/SOURCES.txt'
# running check
# creating ProductionalizingProject-1-0.3
# creating ProductionalizingProject-1-0.3/ProductionalizingProject_1.egg-info
# creating ProductionalizingProject-1-0.3/mypackage
# copying files to ProductionalizingProject-1-0.3...
# copying README.md -> ProductionalizingProject-1-0.3
# copying setup.cfg -> ProductionalizingProject-1-0.3
# copying setup.py -> ProductionalizingProject-1-0.3
# copying ProductionalizingProject_1.egg-info/PKG-INFO -> ProductionalizingProject-1-0.3/ProductionalizingProject_1.egg-info
# copying ProductionalizingProject_1.egg-info/SOURCES.txt -> ProductionalizingProject-1-0.3/ProductionalizingProject_1.egg-info
# copying ProductionalizingProject_1.egg-info/dependency_links.txt -> ProductionalizingProject-1-0.3/ProductionalizingProject_1.egg-info
# copying ProductionalizingProject_1.egg-info/requires.txt -> ProductionalizingProject-1-0.3/ProductionalizingProject_1.egg-info
# copying ProductionalizingProject_1.egg-info/top_level.txt -> ProductionalizingProject-1-0.3/ProductionalizingProject_1.egg-info
# copying mypackage/__init__.py -> ProductionalizingProject-1-0.3/mypackage
# copying mypackage/mymodule.py -> ProductionalizingProject-1-0.3/mypackage
# copying mypackage/template.txt -> ProductionalizingProject-1-0.3/mypackage
# Writing ProductionalizingProject-1-0.3/setup.cfg
# Creating tar archive
# removing 'ProductionalizingProject-1-0.3' (and everything under it)
# Uploading distributions to https://upload.pypi.org/legacy/
# Uploading ProductionalizingProject-1-0.3.tar.gz
# 100%|██████████| 4.34k/4.34k [00:00<00:00, 21.2kB/s]
# You are using pip version 18.1, however version 19.0.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# # Lab
#
# Open [packaging lab][packaging-lab]
#
# [packaging-lab]: ./packaging-lab.ipynb
